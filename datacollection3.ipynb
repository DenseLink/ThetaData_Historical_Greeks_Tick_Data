# %%
import requests
import numpy as np
import pandas as pd
from datetime import time

# %%
import requests
import datetime

def fetch_contracts(root, date, contract_type):
    """
    Fetch contracts data for a given root symbol, date, and contract type,
    and filter the results for the specified root symbol.
    
    :param root: Root symbol of the index, e.g., 'SPX' or 'SPXW'.
    :param date: Date in 'YYYYMMDD' format.
    :param contract_type: Type of contract data to fetch ('trade', 'quote', or 'open_interest').
    :return: Filtered JSON response from the API for the specified root.
    """
    url = f"http://127.0.0.1:25510/v2/list/contracts/option/{contract_type}"
    params = {"start_date": date}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        # Filter the contracts for the specified root symbol
        filtered_contracts = [contract for contract in data['response'] if contract[0] == root]
        return {
            "header": data["header"],
            "response": filtered_contracts
        }
    else:
        #print(f"Failed to fetch contracts for {contract_type}: {response.status_code}, {response.text}")
        return None

#date = "20240223"
# Generate a list of dates from 20240511 to the present day
start_date = datetime.datetime(2023, 8, 9)
end_date = datetime.datetime(2023, 8, 25)

#end_date = datetime.datetime.now()
date_list = [(start_date + datetime.timedelta(days=x)).strftime('%Y%m%d') for x in range((end_date - start_date).days + 1)]





roots = ["SPXW", "SPY", "UVXY","SPX","QQQ","VIX"]
#roots = ["UVXY","VIX","CAT"]
#roots = ["TSLA"]
contract_types = ["trade", "quote", "open_interest"]

# A list to hold dates with contracts found
#dates_with_contracts = []

# Iterate through each date
#for date in date_list:
#    contracts_found = False
#    for root in roots:
#        for contract_type in contract_types:
#            data = fetch_contracts(root, date, contract_type)
#            if data and data["response"]:
#                contracts_found = True
#                print(f"{root} - {date} - {contract_type}: {len(data['response'])} contracts found")
#    if contracts_found:
#        dates_with_contracts.append(date)

# %%
import os
import pandas as pd
import requests
from functools import reduce
import requests
from tqdm import tqdm  # Import tqdm
from datetime import datetime
from datetime import timedelta
import json

def log_strike_error_to_json(error_contracts_list, base_directory="H:\\Financial_Data\\Historical_data"):
    error_folder_name = "Strike_History_Errors"
    error_log_filename = "errors_log.json"
    
    for contract in error_contracts_list:
        root = contract["root"]
        start_date = contract["start_date"]
        error_folder_path = os.path.join(base_directory, root, error_folder_name, start_date)
        error_log_file_path = os.path.join(error_folder_path, error_log_filename)

        if not os.path.exists(error_folder_path):
            os.makedirs(error_folder_path)

        try:
            if os.path.exists(error_log_file_path):
                with open(error_log_file_path, "r") as file:
                    existing_errors = json.load(file)
            else:
                existing_errors = []
        except json.JSONDecodeError:
            existing_errors = []

        # Check for duplicates and append if no duplicates found
        if contract not in existing_errors:
            existing_errors.append(contract)
            with open(error_log_file_path, "w") as file:
                json.dump(existing_errors, file, indent=4)
    
    #print(f"Logged an error for contract: Root={root}, Expiration={expiration}, Strike={strike}, Right={right}, Start_Date={start_date}, End_Date={end_date} to JSON")

def log_strike_success_to_json(successful_contracts_list, base_directory="H:\\Financial_Data\\Historical_data"):
    success_folder_name = "Strike_History_Success"
    success_log_filename = "Completed_log.json"
    
    for contract in successful_contracts_list:
        root = contract["root"]
        start_date = contract["start_date"]
        success_folder_path = os.path.join(base_directory, root, success_folder_name, start_date)
        success_log_file_path = os.path.join(success_folder_path, success_log_filename)

        if not os.path.exists(success_folder_path):
            os.makedirs(success_folder_path)

        try:
            if os.path.exists(success_log_file_path):
                with open(success_log_file_path, "r") as file:
                    existing_data = json.load(file)
            else:
                existing_data = []
        except json.JSONDecodeError:
            existing_data = []
        
        # Check for duplicates and append if no duplicates found
        if contract not in existing_data:
            existing_data.append(contract)
            with open(success_log_file_path, "w") as file:
                json.dump(existing_data, file, indent=4)
    
    #print(f"Logged an error for contract: Root={root}, Expiration={expiration}, Strike={strike}, Right={right}, Start_Date={start_date}, End_Date={end_date} to JSON")

# Function to fetch data, convert to DataFrame, and apply 'ms_to_time'
def fetch_and_format_data(endpoint, columns, root, expiration, strike, right, start_date, end_date):
    interval = 10000
    base_url = "http://127.0.0.1:25510/v2/hist/option/"
    try:
        response = requests.get(f"{base_url}{endpoint}", params={
            "root": root, "exp": expiration, "strike": strike, "right": right,
            "start_date": start_date, "end_date": end_date, "ivl": interval
        })
        response.raise_for_status()  # Ensure we notice bad responses

        # Ensure there is data before attempting to decode JSON
        if response.text:
            data = response.json().get('response', [])
            return pd.DataFrame(data, columns=columns).assign(time_of_day=lambda df: df['ms_of_day'].apply(ms_to_time))
        else:
            # Handle cases where there is no response data
            error_contracts_list.append({
                "root":root,
                "expiration":expiration, 
                "strike":strike, 
                "right":right, 
                "start_date":start_date, 
                "end_date":end_date, 
            })
            return pd.DataFrame(columns=columns)
    except (requests.exceptions.HTTPError, requests.exceptions.RequestException, ValueError) as e:
        # Log the error and return an empty DataFrame
        error_contracts_list.append({
                "root":root,
                "expiration":expiration, 
                "strike":strike, 
                "right":right, 
                "start_date":start_date, 
                "end_date":end_date, 
            })
        return pd.DataFrame(columns=columns)

# Function to convert milliseconds to time of day
def ms_to_time(ms):
    seconds = (ms // 1000) % 60
    minutes = (ms // (1000 * 60)) % 60
    hours = (ms // (1000 * 60 * 60)) % 24
    return f"{hours:02d}:{minutes:02d}:{seconds:02d}"


def fetch_contracts_filtered_by_root(date, contract_type, url):
    """
    Fetch and filter contracts data for given date and contract type, filtering by root symbols.
    """
    #url = f"http://127.0.0.1:25510/v2/list/contracts/option/{contract_type}"
    params = {"start_date": date}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        #print(f"Failed to fetch contracts for {contract_type}: {response.status_code}, {response.text}")
        return []

def collect_contracts_data(date, contract_types, url, url_1, url_2, roots=[""]):
    """
    Check to see if location already exists:
    """
    _base_directory = "H:\\Financial_Data\\Historical_data"
    _contract_list_folder = "CONTRACT_LIST"
    _folder_path = os.path.join(_base_directory, roots[0], _contract_list_folder,date)
    if os.path.exists(_folder_path):
        #print("skipped")
        return
    
    """
    Collect contracts data across specified roots and contract types into a list of dicts.
    """
    trade_contracts = fetch_contracts_filtered_by_root(date, contract_types[0], url)
    quote_contracts = fetch_contracts_filtered_by_root(date, contract_types[1], url_1)
    open_interest_contracts = fetch_contracts_filtered_by_root(date, contract_types[2], url_2)

    # Initialize empty lists to ensure variables are defined
    _trade_contracts = []
    _quote_contracts = []
    _open_interest_contracts = []
    # Filter the contracts by the specified roots and ensure all dicts have the expected keys
    if 'response' in trade_contracts:
        #_trade_contracts = [{"contract_type": "trade", "date": date, **contract} for contract in trade_contracts['response']]
        _trade_contracts = [{
        "contract_type": "trade",
        "date": date,
        "root": contract[0],
        "expiration": contract[1],
        "strike": contract[2],
        "right": contract[3]
    } for contract in trade_contracts['response']]
    if 'response' in quote_contracts:
        #_quote_contracts = [{"contract_type": "quote", "date": date, **contract} for contract in quote_contracts['response']]
        _quote_contracts = [{
        "contract_type": "trade",
        "date": date,
        "root": contract[0],
        "expiration": contract[1],
        "strike": contract[2],
        "right": contract[3]
    } for contract in quote_contracts['response']]
    if 'response' in open_interest_contracts:
        #_open_interest_contracts = [{"contract_type": "open_interest", "date": date, **contract} for contract in open_interest_contracts['response']]
        _open_interest_contracts = [{
        "contract_type": "trade",
        "date": date,
        "root": contract[0],
        "expiration": contract[1],
        "strike": contract[2],
        "right": contract[3]
    } for contract in open_interest_contracts['response']]
        
    filtered_contracts = _trade_contracts+_quote_contracts+_open_interest_contracts
    # Now, filtered_contracts contains dictionaries with a consistent set of keys
    df = pd.DataFrame(filtered_contracts, columns=["root", "expiration", "strike", "right", "contract_type","date"])
    df = df[df['root'].isin(roots)]
    df = df.drop_duplicates(subset=['root', 'expiration', 'strike', 'right'])
    missing_roots = [root for root in roots if root not in df['root'].unique()]
    if missing_roots:
        del df
        return

    base_directory = "H:\\Financial_Data\\Historical_data"
    contract_list_folder = "CONTRACT_LIST"
 
    for root in roots:   
        df_filtered = df[df['root'] == root]
        # Folder path for the current root
        folder_path = os.path.join(base_directory, root, contract_list_folder,date)
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        filename = f"{root}_{date}.json"
        file_path = os.path.join(folder_path, filename)
        df_filtered.to_json(file_path, orient='records', lines=True)
    all_contracts = []   
    for index, row in df.iterrows():
        contract_dict = {
            "root": row['root'],
            "expiration": row['expiration'],
            "strike": row['strike'],
            "right": row['right'],
            "contract_type": row['contract_type'],
            "date": row['date']
        }
        all_contracts.append(contract_dict)
    del df
    del df_filtered
    return all_contracts


# Function to check and drop identical columns
def check_and_drop_identical_columns(df, potential_duplicates, suffix):
    for duplicate_col in potential_duplicates:
        # Remove the suffix to find the original column name
        # Ensure to handle different suffix lengths accurately
        #second_order_col=''
        if suffix == '_greeks':
            original_col = duplicate_col[:-7]  # '_greeks' has 7 characters
            #print(potential_duplicates)
            #print(original_col)
            #print(duplicate_col)
        elif suffix == '_greeks_second_order':
            #print(duplicate_col[:-20])
            original_col = duplicate_col[:-20] # '_greeks_second_order' has 20 characters
            first_order_col = original_col+'_greeks'
        elif suffix == '_greeks_third_order':
            #print(duplicate_col[:-19])
            original_col = duplicate_col[:-19] # '_greeks_third_order' has 19 characters
            first_order_col = original_col+'_greeks'
            second_order_col = original_col+'_greeks_second_order'
            #print(first_order_col)
            #print(second_order_col)
        else:
            original_col = duplicate_col
        
        # Check if the original column exists in the DataFrame
        if original_col in df.columns:
            # Check if the original column's data equals the duplicate column's data
            if df[original_col].equals(df[duplicate_col]):
                #print(original_col)
                #print(duplicate_col)
                #print('end')
                # Drop the duplicate column if the data is identical
                df.drop(columns=[duplicate_col], inplace=True)
        if suffix == '_greeks_second_order' or suffix == '_greeks_third_order':
            if first_order_col in df.columns:
                if df[first_order_col].equals(df[duplicate_col]):
                    df.drop(columns=[duplicate_col], inplace=True)
        if suffix == '_greeks_third_order':
            if second_order_col in df.columns:
                #print(second_order_col)
                if df[second_order_col].equals(df[duplicate_col]):
                    df.drop(columns=[duplicate_col], inplace=True)
        #print(df.columns)












def process_contracts(root, expiration, strike, right, start_date, end_date):
    # Assuming 'first_contract' is already defined as the first row of your initial DataFrame
    
    # Define constants
    interval = "10000"
    base_directory="H:\\Financial_Data\\Historical_data"
    # Base URL for API requests
    base_url = "http://127.0.0.1:25510/v2/hist/option/"

    # Columns for each DataFrame
    columns_quote = ['ms_of_day', 'bid_size', 'bid_exchange', 'bid', 'bid_condition', 'ask_size', 'ask_exchange', 'ask', 'ask_condition', 'date']
    columns_iv = ['ms_of_day', 'bid', 'bid_implied_vol', 'midpoint', 'mid_implied_vol', 'ask', 'ask_implied_vol', 'iv_error', 'ms_of_day2', 'underlying_price', 'date']
    columns_greeks = ['ms_of_day', 'bid2', 'ask2', 'delta', 'theta', 'vega', 'rho', 'epsilon', 'lamba', 'implied_vol', 'iv_error2', 'ms_of_day22', 'underlying_price2', 'date']
    columns_greeks_2nd_order = ['ms_of_day', 'bid3', 'ask3', 'gamma', 'vanna', 'charm', 'vomma', 'veta', 'implied_vol3', 'iv_error3', 'ms_of_day23', 'underlying_price3', 'date']
    columns_greeks_3rd_order = ['ms_of_day', 'bid4', 'ask4', 'speed', 'zomma', 'color', 'ultima', 'implied_vol4', 'iv_error4', 'ms_of_day24', 'underlying_price4', 'date']


    # Fetch and format data for each DataFrame
    df1 = fetch_and_format_data("quote", columns_quote, root, expiration, strike, right, start_date, end_date)
    df2 = fetch_and_format_data("implied_volatility", columns_iv, root, expiration, strike, right, start_date, end_date)
    df3 = fetch_and_format_data("greeks", columns_greeks, root, expiration, strike, right, start_date, end_date)
    df3.rename(columns={'time_of_day': 'time_of_day_x'}, inplace=True)
    df4 = fetch_and_format_data("greeks_second_order", columns_greeks_2nd_order, root, expiration, strike, right, start_date, end_date)
    df4.rename(columns={'time_of_day': 'time_of_day_y'}, inplace=True)
    df5 = fetch_and_format_data("greeks_third_order", columns_greeks_3rd_order, root, expiration, strike, right, start_date, end_date)
    df5.rename(columns={'time_of_day': 'time_of_day_z'}, inplace=True)

    # List of all DataFrames to merge
    dfs = [df2, df3, df4, df5]

    # Merge all DataFrames on 'ms_of_day' and 'date' using functools.reduce
    #merged_df = reduce(lambda left, right: pd.merge(left, right, on=['ms_of_day', 'date'], how='outer'), dfs)
   # merged_df = reduce(lambda left, right: pd.merge(left, right, on=['ms_of_day', 'date'], how='outer', suffixes=('_left', '_right')), dfs)
    # Example of renaming conflicting columns in all DataFrames
    #for i, df in enumerate(dfs):
     #   suffix = f"_df{i+1}"
      #  conflicting_columns = ['bid', 'ask', 'iv_error', 'ms_of_day2', 'underlying_price']
       # df.rename(columns={col: col + suffix for col in conflicting_columns if col in df.columns}, inplace=True)

    # Now merge them
    merged_df = reduce(lambda left, right: pd.merge(left, right, on=['ms_of_day', 'date'], how='outer'), dfs)
    #merged_df.rename(columns={'time_of_day_x': 'time_of_day'}, inplace=True)


    

    # Define the columns you want to keep as per the IV_Greeks specification
    iv_greeks_columns = [
        'ms_of_day', 'time_of_day', 'bid', 'bid_implied_vol', 'midpoint', 'mid_implied_vol', 'ask', 'ask_implied_vol',
        'iv_error', 'ms_of_day2', 'underlying_price', 'date', 'delta', 'theta', 'vega', 'rho', 'epsilon', 'lamba',
        'implied_vol', 'gamma', 'vanna', 'charm', 'vomma', 'veta', 'speed', 'zomma', 'color', 'ultima'
    ]

    # Keep only the columns specified in iv_greeks_columns
    final_df = merged_df[iv_greeks_columns]



    quote_column_order = [
        'ms_of_day', 'time_of_day', 'bid_size', 'bid_exchange', 'bid', 'bid_condition', 
        'ask_size', 'ask_exchange', 'ask', 'ask_condition', 'date'
    ]

    # Reorder the columns in 'df_quote'
    df_quote = df1[quote_column_order]



     #The final DataFrame is ready; now save it to the appropriate JSON file
    folder_path_iv = os.path.join(base_directory, root, 'IV_Greeks', start_date)
    folder_path_quotes = os.path.join(base_directory, root, 'QUOTES', start_date)
    
    if not os.path.exists(folder_path_iv):
        os.makedirs(folder_path_iv, exist_ok=True)
    if not os.path.exists(folder_path_quotes):
        os.makedirs(folder_path_quotes, exist_ok=True)
    
    file_path_iv = os.path.join(folder_path_iv, f"{root}_{start_date}_{expiration}_{strike}_{right}.json")
    file_path_quotes = os.path.join(folder_path_quotes, f"{root}_{start_date}_{expiration}_{strike}_{right}.json")

    final_df.to_json(file_path_iv, orient='records', lines=True)
    df_quote.to_json(file_path_quotes, orient='records', lines=True)

    # Log success
    successful_contracts_list.append({
                "root":root,
                "expiration":expiration, 
                "strike":strike, 
                "right":right, 
                "start_date":start_date, 
                "end_date":end_date, 
            })
    del df1
    del df2
    del df3
    del df4
    del df5
    del dfs
    del merged_df
    del final_df
    del df_quote

    
def load_logged_contracts(folder_path, filename):
    file_path = os.path.join(folder_path, filename)
    if os.path.exists(file_path):
        with open(file_path, "r") as file:
            try:
                return json.load(file)
            except json.JSONDecodeError:
                return []  # or handle the error as needed
    return []    
    
def get_normalized_entry(entry, keys):
    # Normalize the dictionary keys to lowercase
    normalized_entry = {k.lower(): entry.get(k) or entry.get(k.capitalize()) for k in keys}
    return tuple(normalized_entry[k] for k in keys)

# Example usage
#date = "20240220"
url = f"http://127.0.0.1:25510/v2/list/contracts/option/trade"
url_1 = f"http://127.0.0.1:25510/v2/list/contracts/option/quote"
url_2 = f"http://127.0.0.1:25510/v2/list/contracts/option/open_interest"
#params = {"start_date": date}
#response = requests.get(url, params=params)
#data = response.json()
contract_types = ["trade", "quote", "open_interest"]
#contracts_data = []  # Initialize as empty list


Trading_Days = ["SPXW", "SPY", "UVXY","SPX","QQQ","VIX","CAT","TSLA"]
for date in tqdm(date_list, desc="Total Contracts for Project Complete"):
    #contracts_data.extend(collect_contracts_data(date, contract_types, roots))
    contracts_data = collect_contracts_data(date, contract_types, url, url_1, url_2, Trading_Days)
  

base_directory = "H:\\Financial_Data\\Historical_data"
contract_list_folder = "CONTRACT_LIST"

#i=0
special_roots = {'SPXW', 'QQQ', 'SPY'}
_spx_root = {'SPX'}
_spxw_root = {'SPXW'}
_qqq_root = {'QQQ'}
_spy_root = {'SPY'}
for date in tqdm(date_list, desc="Total Project Complete"):    
    daily_contracts = []  # Initialize the list for daily contracts
    
    # Collect all file paths first
    file_paths = [os.path.join(base_directory, root, contract_list_folder, date, f"{root}_{date}.json") for root in roots]
    file_paths = [path for path in file_paths if os.path.exists(path)]

    current_date = datetime.strptime(date, '%Y%m%d')
    
    # Load dataframes if file exists
    daily_contracts = [pd.read_json(path, lines=True) for path in file_paths]
    
    # Concatenate all dataframes for the current day
    if daily_contracts:
        df = pd.concat(daily_contracts, ignore_index=True)
        #print("round SPX ")
        #print(df[df['root'] == 'SPX']['expiration'].unique())
        #print(df[(df['root'] == 'SPX') & (df['root'] != 'SPXW')]['expiration'].unique())

        
        
        #print("SPXW ")
        #print(df[df['root'] == 'SPXW']['expiration'].unique())
        
        #print("round SPX ")
        #print(df[df['root'] == 'SPX']['expiration'].unique())
        
        #print("round UVXY ")
        #print(df[df['root'] == 'UVXY']['expiration'].unique())

        #print("round SPY ")
        #print(df[df['root'] == 'SPY']['expiration'].unique())
        
        #print("round QQQ ")
        #print(df[df['root'] == 'QQQ']['expiration'].unique())

        #print("round VIX ")
        #print(df[df['root'] == 'VIX']['expiration'].unique())

        #print("round CAT ")
        #print(df[df['root'] == 'CAT']['expiration'].unique())
        
        
        filtered_dfs = []
        for root in df['root'].unique():
            root_df = df[df['root'] == root]  # Filter the DataFrame for the current root
            if root in _spxw_root:
                future_expirations = root_df[root_df['expiration'] >= int(current_date.strftime('%Y%m%d'))]['expiration'].unique()
                unique_expirations = sorted(future_expirations)[:3]
                filtered_root_df = root_df[root_df['expiration'].isin(unique_expirations)]

            elif root in _qqq_root:
                future_expirations = root_df[root_df['expiration'] >= int(current_date.strftime('%Y%m%d'))]['expiration'].unique()
                unique_expirations = sorted(future_expirations)[:3]
                filtered_root_df = root_df[root_df['expiration'].isin(unique_expirations)]

            elif root in _spy_root:
                future_expirations = root_df[root_df['expiration'] >= int(current_date.strftime('%Y%m%d'))]['expiration'].unique()
                unique_expirations = sorted(future_expirations)[:3]
                filtered_root_df = root_df[root_df['expiration'].isin(unique_expirations)]

            elif root in _spx_root:
                future_expirations = root_df[root_df['expiration'] >= int(current_date.strftime('%Y%m%d'))]['expiration'].unique()
                unique_expirations = sorted(future_expirations)[:3]
                filtered_root_df = root_df[root_df['expiration'].isin(unique_expirations)]
            #elif root == 'UVXY':
            #    future_expirations = root_df[root_df['expiration'] >= int(current_date.strftime('%Y%m%d'))]
            #    filtered_dfs.append(future_expirations)
            #elif root == 'VIX':
            #    future_expirations = root_df[root_df['expiration'] >= int(current_date.strftime('%Y%m%d'))]
            #    filtered_dfs.append(future_expirations)
            else:
                filtered_dfs.append(df[df['root'] == root])
            filtered_dfs.append(filtered_root_df)
        df = pd.concat(filtered_dfs).reset_index(drop=True)
        #print("SPXW ")
        #print(df[df['root'] == 'SPXW']['expiration'].unique())
        
        #print("round SPX ")
        #print(df[df['root'] == 'SPX']['expiration'].unique())
        
        #print("round UVXY ")
        #print(df[df['root'] == 'UVXY']['expiration'].unique())

        #print("round SPY ")
        #print(df[df['root'] == 'SPY']['expiration'].unique())
        
        #print("round QQQ ")
        #print(df[df['root'] == 'QQQ']['expiration'].unique())

        #print("round VIX ")
        #print(df[df['root'] == 'VIX']['expiration'].unique())

        #print("round CAT ")
        #print(df[df['root'] == 'CAT']['expiration'].unique())


    else:
        continue  # Skip to next date if no contracts

    success_folder_name = "Strike_History_Success"
    error_folder_name = "Strike_History_Errors"
    conditional_descriptor = 'a'
    successful_contracts_list = []
    error_contracts_list = []
    i = 1
    tqdm_iterator = tqdm(df.iterrows(), desc="Processing contracts")
    for index, contract in tqdm_iterator:
        desc = f"Root: {contract['root']}, Strike: {contract['strike']}, Expiration: {contract['expiration']}, Right: {contract['right']}, Date: {contract['date']}, Contract:{i}"
        tqdm_iterator.set_description(desc)
        if conditional_descriptor != contract['root']:
            i = 0
            conditional_descriptor = contract['root']
            log_strike_success_to_json(successful_contracts_list, base_directory)
            log_strike_error_to_json(error_contracts_list, base_directory)
            # After processing and logging for the current root
            successful_contracts_list = []
            error_contracts_list = []

            
            
        i = i+1
        # Define constants
        root = str(contract['root'])
        expiration = str(contract['expiration'])
        strike = str(contract['strike'])
        right = str(contract['right'])
        start_date = str(contract['date'])  # Assuming 'date' is in 'YYYYMMDD' format
        end_date = str(contract['date']) 


        success_folder_path = os.path.join(base_directory, root, success_folder_name, start_date)
        error_folder_path = os.path.join(base_directory, root, error_folder_name, start_date)
        success_contracts = load_logged_contracts(success_folder_path, 'Completed_log.json')
        error_contracts = load_logged_contracts(error_folder_path, 'errors_log.json')
        
        # Define a set or dictionary for quicker search
        success_entries = {(entry["root"], entry["expiration"], entry["strike"], entry["right"], entry["start_date"], entry["end_date"]) for entry in success_contracts}
        error_entries = {(entry["root"], entry["expiration"], entry["strike"], entry["right"], entry["start_date"], entry["end_date"]) for entry in error_contracts}
        #only run below if debugging
            #keys = ["root", "expiration", "strike", "right", "start_date", "end_date"]

            #success_entries = {get_normalized_entry(entry, keys) for entry in success_contracts}
            #error_entries = {get_normalized_entry(entry, keys) for entry in error_contracts}


        
        contract_tuple = (root, expiration, strike, right, start_date, end_date)
        #i = i+1
        #if i == 850:
            #print('hi')
        if contract_tuple in success_entries or contract_tuple in error_entries:
            #print('skipped')
            continue
        try:
            #print
            process_contracts(root,  expiration, strike, right, start_date, end_date)
        except KeyError as e:
            error_contracts_list.append({
                "root":root,
                "expiration":expiration, 
                "strike":strike, 
                "right":right, 
                "start_date":start_date, 
                "end_date":end_date, 
            })
# Out:
# Total Contracts for Project Complete: 100%|███████████████████████████████████████████████████████| 17/17 [00:11<00:00,  1.44it/s]
# Total Project Complete:   0%|                                                                              | 0/17 [00:00<?, ?it/s]
# Processing contracts: 0it [00:00, ?it/s]
# Root: SPXW, Strike: 4425000, Expiration: 20230809, Right: P, Date: 20230809, Contract:1: : 0it [00:00, ?it/s]
# Root: SPXW, Strike: 4425000, Expiration: 20230809, Right: C, Date: 20230809, Contract:1: : 0it [00:00, ?it/s]
# Root: SPXW, Strike: 4425000, Expiration: 20230809, Right: C, Date: 20230809, Contract:1: : 2it [00:01,  1.10it/s]
# Root: SPXW, Strike: 3900000, Expiration: 20230810, Right: P, Date: 20230809, Contract:2: : 2it [00:01,  1.10it/s]
# Root: SPXW, Strike: 3900000, Expiration: 20230811, Right: P, Date: 20230809, Contract:3: : 2it [00:01,  1.10it/s]
# Root: SPXW, Strike: 4425000, Expiration: 20230810, Right: P, Date: 20230809, Contract:4: : 2it [00:01,  1.10it/s]
# Root: SPXW, Strike: 4425000, Expiration: 20230810, Right: C, Date: 20230809, Contract:5: : 2it [00:01,  1.10it/s]
# Root: SPXW, Strike: 4425000, Expiration: 20230810, Right: C, Date: 20230809, Contract:5: : 6it [00:05,  1.04it/s]
# Root: SPXW, Strike: 4430000, Expiration: 20230809, Right: P, Date: 20230809, Contract:6: : 6it [00:05,  1.04it/s]
# Root: SPXW, Strike: 4430000, Expiration: 20230809, Right: C, Date: 20230809, Contract:7: : 6it [00:05,  1.04it/s]
# Root: SPXW, Strike: 4430000, Expiration: 20230809, Right: C, Date: 20230809, Contract:7: : 8it [00:10,  1.52s/it]
# Root: SPXW, Strike: 4425000, Expiration: 20230811, Right: P, Date: 20230809, Contract:8: : 8it [00:10,  1.52s/it]
# Root: SPXW, Strike: 4425000, Expiration: 20230811, Right: C, Date: 20230809, Contract:9: : 8it [00:10,  1.52s/it]
# Root: SPXW, Strike: 4425000, Expiration: 20230811, Right: C, Date: 20230809, Contract:9: : 10it [00:15,  1.73s/it]
# Root: SPXW, Strike: 4435000, Expiration: 20230809, Right: P, Date: 20230809, Contract:10: : 10it [00:15,  1.73s/it]
# Root: SPXW, Strike: 4435000, Expiration: 20230809, Right: C, Date: 20230809, Contract:11: : 10it [00:15,  1.73s/it]
# Root: SPXW, Strike: 4435000, Expiration: 20230809, Right: C, Date: 20230809, Contract:11: : 12it [00:18,  1.75s/it]
# Root: SPXW, Strike: 4430000, Expiration: 20230810, Right: P, Date: 20230809, Contract:12: : 12it [00:18,  1.75s/it]
# Root: SPXW, Strike: 4430000, Expiration: 20230810, Right: C, Date: 20230809, Contract:13: : 12it [00:18,  1.75s/it]
# Root: SPXW, Strike: 4430000, Expiration: 20230810, Right: C, Date: 20230809, Contract:13: : 14it [00:21,  1.62s/it]
# Root: SPXW, Strike: 4430000, Expiration: 20230811, Right: P, Date: 20230809, Contract:14: : 14it [00:21,  1.62s/it]
# Root: SPXW, Strike: 4430000, Expiration: 20230811, Right: C, Date: 20230809, Contract:15: : 14it [00:21,  1.62s/it]
# Root: SPXW, Strike: 4430000, Expiration: 20230811, Right: C, Date: 20230809, Contract:15: : 16it [00:25,  1.69s/it]
# Root: SPXW, Strike: 4440000, Expiration: 20230809, Right: P, Date: 20230809, Contract:16: : 16it [00:25,  1.69s/it]
# Root: SPXW, Strike: 4440000, Expiration: 20230809, Right: C, Date: 20230809, Contract:17: : 16it [00:25,  1.69s/it]
# Root: SPXW, Strike: 4440000, Expiration: 20230809, Right: C, Date: 20230809, Contract:17: : 18it [00:33,  2.38s/it]
# Root: SPXW, Strike: 3910000, Expiration: 20230811, Right: P, Date: 20230809, Contract:18: : 18it [00:33,  2.38s/it]
# Root: SPXW, Strike: 4435000, Expiration: 20230810, Right: P, Date: 20230809, Contract:19: : 18it [00:33,  2.38s/it]
# Root: SPXW, Strike: 4435000, Expiration: 20230810, Right: C, Date: 20230809, Contract:20: : 18it [00:33,  2.38s/it]
# Root: SPXW, Strike: 4435000, Expiration: 20230810, Right: C, Date: 20230809, Contract:20: : 21it [00:35,  1.73s/it]
# Root: SPXW, Strike: 4435000, Expiration: 20230811, Right: P, Date: 20230809, Contract:21: : 21it [00:35,  1.73s/it]
# Root: SPXW, Strike: 4435000, Expiration: 20230811, Right: C, Date: 20230809, Contract:22: : 21it [00:35,  1.73s/it]
# Root: SPXW, Strike: 4435000, Expiration: 20230811, Right: C, Date: 20230809, Contract:22: : 23it [00:38,  1.77s/it]
# Root: SPXW, Strike: 4445000, Expiration: 20230809, Right: P, Date: 20230809, Contract:23: : 23it [00:38,  1.77s/it]
# Root: SPXW, Strike: 4440000, Expiration: 20230810, Right: P, Date: 20230809, Contract:24: : 23it [00:38,  1.77s/it]
# Root: SPXW, Strike: 4445000, Expiration: 20230809, Right: C, Date: 20230809, Contract:25: : 23it [00:38,  1.77s/it]
# Root: SPXW, Strike: 4445000, Expiration: 20230809, Right: C, Date: 20230809, Contract:25: : 26it [00:41,  1.37s/it]
# Root: SPXW, Strike: 4440000, Expiration: 20230810, Right: C, Date: 20230809, Contract:26: : 26it [00:41,  1.37s/it]
# Root: SPXW, Strike: 4440000, Expiration: 20230810, Right: C, Date: 20230809, Contract:26: : 27it [00:48,  2.24s/it]
# Root: SPXW, Strike: 4440000, Expiration: 20230811, Right: P, Date: 20230809, Contract:27: : 27it [00:48,  2.24s/it]
# Root: SPXW, Strike: 4440000, Expiration: 20230811, Right: C, Date: 20230809, Contract:28: : 27it [00:48,  2.24s/it]
# Root: SPXW, Strike: 4440000, Expiration: 20230811, Right: C, Date: 20230809, Contract:28: : 29it [00:51,  2.13s/it]
# Root: SPXW, Strike: 3920000, Expiration: 20230811, Right: P, Date: 20230809, Contract:29: : 29it [00:51,  2.13s/it]
# Root: SPXW, Strike: 4445000, Expiration: 20230810, Right: P, Date: 20230809, Contract:30: : 29it [00:51,  2.13s/it]
# Root: SPXW, Strike: 4445000, Expiration: 20230810, Right: C, Date: 20230809, Contract:31: : 29it [00:51,  2.13s/it]
# Root: SPXW, Strike: 4445000, Expiration: 20230810, Right: C, Date: 20230809, Contract:31: : 32it [00:55,  1.81s/it]
# Root: SPXW, Strike: 4445000, Expiration: 20230811, Right: P, Date: 20230809, Contract:32: : 32it [00:55,  1.81s/it]
# Root: SPXW, Strike: 4445000, Expiration: 20230811, Right: C, Date: 20230809, Contract:33: : 32it [00:55,  1.81s/it]
# Root: SPXW, Strike: 4445000, Expiration: 20230811, Right: C, Date: 20230809, Contract:33: : 34it [00:59,  1.84s/it]
# Root: SPXW, Strike: 4450000, Expiration: 20230809, Right: P, Date: 20230809, Contract:34: : 34it [00:59,  1.84s/it]
# Root: SPXW, Strike: 4450000, Expiration: 20230809, Right: C, Date: 20230809, Contract:35: : 34it [00:59,  1.84s/it]
# Root: SPXW, Strike: 4450000, Expiration: 20230809, Right: C, Date: 20230809, Contract:35: : 36it [01:06,  2.25s/it]
# Root: SPXW, Strike: 3925000, Expiration: 20230810, Right: P, Date: 20230809, Contract:36: : 36it [01:06,  2.25s/it]
# Root: SPXW, Strike: 3400000, Expiration: 20230811, Right: P, Date: 20230809, Contract:37: : 36it [01:06,  2.25s/it]
# Root: SPXW, Strike: 3925000, Expiration: 20230811, Right: P, Date: 20230809, Contract:38: : 36it [01:06,  2.25s/it]
# Root: SPXW, Strike: 4450000, Expiration: 20230810, Right: P, Date: 20230809, Contract:39: : 36it [01:06,  2.25s/it]
# Root: SPXW, Strike: 4450000, Expiration: 20230810, Right: C, Date: 20230809, Contract:40: : 36it [01:06,  2.25s/it]
# Root: SPXW, Strike: 4450000, Expiration: 20230810, Right: C, Date: 20230809, Contract:40: : 41it [01:11,  1.61s/it]
# Root: SPXW, Strike: 4450000, Expiration: 20230811, Right: C, Date: 20230809, Contract:41: : 41it [01:11,  1.61s/it]
# Root: SPXW, Strike: 4450000, Expiration: 20230811, Right: P, Date: 20230809, Contract:42: : 41it [01:11,  1.61s/it]
# Root: SPXW, Strike: 4450000, Expiration: 20230811, Right: P, Date: 20230809, Contract:42: : 43it [01:18,  2.07s/it]
# Root: SPXW, Strike: 4455000, Expiration: 20230809, Right: P, Date: 20230809, Contract:43: : 43it [01:18,  2.07s/it]
# Root: SPXW, Strike: 4455000, Expiration: 20230809, Right: C, Date: 20230809, Contract:44: : 43it [01:18,  2.07s/it]
# Root: SPXW, Strike: 4455000, Expiration: 20230809, Right: C, Date: 20230809, Contract:44: : 45it [01:25,  2.43s/it]
# Root: SPXW, Strike: 3930000, Expiration: 20230811, Right: P, Date: 20230809, Contract:45: : 45it [01:25,  2.43s/it]
# Root: SPXW, Strike: 4455000, Expiration: 20230811, Right: P, Date: 20230809, Contract:46: : 45it [01:25,  2.43s/it]
# Root: SPXW, Strike: 4455000, Expiration: 20230811, Right: C, Date: 20230809, Contract:47: : 45it [01:25,  2.43s/it]
# Root: SPXW, Strike: 4455000, Expiration: 20230811, Right: C, Date: 20230809, Contract:47: : 48it [01:28,  1.89s/it]
# Root: SPXW, Strike: 4455000, Expiration: 20230810, Right: P, Date: 20230809, Contract:48: : 48it [01:28,  1.89s/it]
# Root: SPXW, Strike: 4455000, Expiration: 20230810, Right: C, Date: 20230809, Contract:49: : 48it [01:28,  1.89s/it]
# Root: SPXW, Strike: 4455000, Expiration: 20230810, Right: C, Date: 20230809, Contract:49: : 50it [01:33,  2.08s/it]
# Root: SPXW, Strike: 4460000, Expiration: 20230809, Right: C, Date: 20230809, Contract:50: : 50it [01:33,  2.08s/it]
# Root: SPXW, Strike: 4460000, Expiration: 20230809, Right: P, Date: 20230809, Contract:51: : 50it [01:33,  2.08s/it]
# Root: SPXW, Strike: 4460000, Expiration: 20230809, Right: P, Date: 20230809, Contract:51: : 52it [01:39,  2.30s/it]
# Root: SPXW, Strike: 4460000, Expiration: 20230811, Right: P, Date: 20230809, Contract:52: : 52it [01:39,  2.30s/it]
# Root: SPXW, Strike: 4460000, Expiration: 20230811, Right: C, Date: 20230809, Contract:53: : 52it [01:39,  2.30s/it]
# Root: SPXW, Strike: 4460000, Expiration: 20230811, Right: C, Date: 20230809, Contract:53: : 54it [01:43,  2.26s/it]
# Root: SPXW, Strike: 4460000, Expiration: 20230810, Right: P, Date: 20230809, Contract:54: : 54it [01:43,  2.26s/it]
# Root: SPXW, Strike: 4460000, Expiration: 20230810, Right: C, Date: 20230809, Contract:55: : 54it [01:43,  2.26s/it]
# Root: SPXW, Strike: 4460000, Expiration: 20230810, Right: C, Date: 20230809, Contract:55: : 56it [01:47,  2.10s/it]
# Root: SPXW, Strike: 3940000, Expiration: 20230811, Right: P, Date: 20230809, Contract:56: : 56it [01:47,  2.10s/it]
# Root: SPXW, Strike: 4465000, Expiration: 20230809, Right: P, Date: 20230809, Contract:57: : 56it [01:47,  2.10s/it]
# Root: SPXW, Strike: 4465000, Expiration: 20230811, Right: C, Date: 20230809, Contract:58: : 56it [01:47,  2.10s/it]
# Root: SPXW, Strike: 4465000, Expiration: 20230809, Right: C, Date: 20230809, Contract:59: : 56it [01:47,  2.10s/it]
# Root: SPXW, Strike: 4465000, Expiration: 20230809, Right: C, Date: 20230809, Contract:59: : 60it [01:50,  1.54s/it]
# Root: SPXW, Strike: 4465000, Expiration: 20230811, Right: P, Date: 20230809, Contract:60: : 60it [01:50,  1.54s/it]
# Root: SPXW, Strike: 4465000, Expiration: 20230811, Right: P, Date: 20230809, Contract:60: : 61it [01:54,  1.91s/it]
# Root: SPXW, Strike: 4465000, Expiration: 20230810, Right: P, Date: 20230809, Contract:61: : 61it [01:54,  1.91s/it]
# Root: SPXW, Strike: 4465000, Expiration: 20230810, Right: C, Date: 20230809, Contract:62: : 61it [01:54,  1.91s/it]
# Root: SPXW, Strike: 4465000, Expiration: 20230810, Right: C, Date: 20230809, Contract:62: : 63it [01:56,  1.63s/it]
# Root: SPXW, Strike: 4470000, Expiration: 20230811, Right: C, Date: 20230809, Contract:63: : 63it [01:56,  1.63s/it]
# Root: SPXW, Strike: 4470000, Expiration: 20230811, Right: P, Date: 20230809, Contract:64: : 63it [01:56,  1.63s/it]
# Root: SPXW, Strike: 4470000, Expiration: 20230811, Right: P, Date: 20230809, Contract:64: : 65it [02:02,  2.04s/it]
# Root: SPXW, Strike: 4470000, Expiration: 20230809, Right: P, Date: 20230809, Contract:65: : 65it [02:02,  2.04s/it]
# Root: SPXW, Strike: 3950000, Expiration: 20230811, Right: P, Date: 20230809, Contract:66: : 65it [02:02,  2.04s/it]
# Root: SPXW, Strike: 4470000, Expiration: 20230809, Right: C, Date: 20230809, Contract:67: : 65it [02:02,  2.04s/it]
# Root: SPXW, Strike: 4470000, Expiration: 20230809, Right: C, Date: 20230809, Contract:67: : 68it [02:10,  2.31s/it]
# Root: SPXW, Strike: 4470000, Expiration: 20230810, Right: P, Date: 20230809, Contract:68: : 68it [02:10,  2.31s/it]
# Root: SPXW, Strike: 4470000, Expiration: 20230810, Right: C, Date: 20230809, Contract:69: : 68it [02:10,  2.31s/it]
# Root: SPXW, Strike: 4470000, Expiration: 20230810, Right: C, Date: 20230809, Contract:69: : 70it [02:15,  2.27s/it]
# Root: SPXW, Strike: 4475000, Expiration: 20230811, Right: P, Date: 20230809, Contract:70: : 70it [02:15,  2.27s/it]
# Root: SPXW, Strike: 4475000, Expiration: 20230811, Right: C, Date: 20230809, Contract:71: : 70it [02:15,  2.27s/it]
# Root: SPXW, Strike: 4475000, Expiration: 20230811, Right: C, Date: 20230809, Contract:71: : 72it [02:20,  2.33s/it]
# Root: SPXW, Strike: 3950000, Expiration: 20230810, Right: P, Date: 20230809, Contract:72: : 72it [02:20,  2.33s/it]
# Root: SPXW, Strike: 3950000, Expiration: 20230810, Right: C, Date: 20230809, Contract:73: : 72it [02:20,  2.33s/it]
# Root: SPXW, Strike: 3950000, Expiration: 20230810, Right: C, Date: 20230809, Contract:73: : 74it [02:26,  2.54s/it]
# Root: SPXW, Strike: 5000000, Expiration: 20230811, Right: P, Date: 20230809, Contract:74: : 74it [02:26,  2.54s/it]
# Root: SPXW, Strike: 4475000, Expiration: 20230809, Right: C, Date: 20230809, Contract:75: : 74it [02:26,  2.54s/it]
# Root: SPXW, Strike: 4475000, Expiration: 20230809, Right: P, Date: 20230809, Contract:76: : 74it [02:26,  2.54s/it]
# Root: SPXW, Strike: 4475000, Expiration: 20230809, Right: P, Date: 20230809, Contract:76: : 77it [02:29,  1.96s/it]
# Root: SPXW, Strike: 4480000, Expiration: 20230811, Right: C, Date: 20230809, Contract:77: : 77it [02:29,  1.96s/it]
# Root: SPXW, Strike: 4475000, Expiration: 20230810, Right: C, Date: 20230809, Contract:78: : 77it [02:29,  1.96s/it]
# Root: SPXW, Strike: 4480000, Expiration: 20230811, Right: P, Date: 20230809, Contract:79: : 77it [02:29,  1.96s/it]
# Root: SPXW, Strike: 4480000, Expiration: 20230811, Right: P, Date: 20230809, Contract:79: : 80it [02:32,  1.65s/it]
# Root: SPXW, Strike: 4475000, Expiration: 20230810, Right: P, Date: 20230809, Contract:80: : 80it [02:32,  1.65s/it]
# Root: SPXW, Strike: 4475000, Expiration: 20230810, Right: P, Date: 20230809, Contract:80: : 81it [02:41,  2.71s/it]
# Root: SPXW, Strike: 3960000, Expiration: 20230811, Right: P, Date: 20230809, Contract:81: : 81it [02:41,  2.71s/it]
# Root: SPXW, Strike: 4485000, Expiration: 20230811, Right: C, Date: 20230809, Contract:82: : 81it [02:41,  2.71s/it]
# Root: SPXW, Strike: 4480000, Expiration: 20230809, Right: C, Date: 20230809, Contract:83: : 81it [02:41,  2.71s/it]
# Root: SPXW, Strike: 4485000, Expiration: 20230811, Right: P, Date: 20230809, Contract:84: : 81it [02:41,  2.71s/it]
# Root: SPXW, Strike: 4485000, Expiration: 20230811, Right: P, Date: 20230809, Contract:84: : 85it [02:44,  1.82s/it]
# Root: SPXW, Strike: 4480000, Expiration: 20230809, Right: P, Date: 20230809, Contract:85: : 85it [02:44,  1.82s/it]
# Root: SPXW, Strike: 4480000, Expiration: 20230809, Right: P, Date: 20230809, Contract:85: : 86it [02:49,  2.20s/it]
# Root: SPXW, Strike: 4480000, Expiration: 20230810, Right: P, Date: 20230809, Contract:86: : 86it [02:49,  2.20s/it]
# Root: SPXW, Strike: 4480000, Expiration: 20230810, Right: C, Date: 20230809, Contract:87: : 86it [02:49,  2.20s/it]
# Root: SPXW, Strike: 4480000, Expiration: 20230810, Right: C, Date: 20230809, Contract:87: : 88it [02:54,  2.42s/it]
# Root: SPXW, Strike: 4490000, Expiration: 20230811, Right: C, Date: 20230809, Contract:88: : 88it [02:54,  2.42s/it]
# Root: SPXW, Strike: 4490000, Expiration: 20230811, Right: P, Date: 20230809, Contract:89: : 88it [02:54,  2.42s/it]
# Root: SPXW, Strike: 4490000, Expiration: 20230811, Right: P, Date: 20230809, Contract:89: : 90it [02:57,  2.03s/it]
# Root: SPXW, Strike: 3970000, Expiration: 20230811, Right: P, Date: 20230809, Contract:90: : 90it [02:57,  2.03s/it]
# Root: SPXW, Strike: 4485000, Expiration: 20230809, Right: P, Date: 20230809, Contract:91: : 90it [02:57,  2.03s/it]
# Root: SPXW, Strike: 4485000, Expiration: 20230810, Right: P, Date: 20230809, Contract:92: : 90it [02:57,  2.03s/it]
# Root: SPXW, Strike: 4485000, Expiration: 20230809, Right: C, Date: 20230809, Contract:93: : 90it [02:57,  2.03s/it]
# Root: SPXW, Strike: 4485000, Expiration: 20230809, Right: C, Date: 20230809, Contract:93: : 94it [03:01,  1.64s/it]
# Root: SPXW, Strike: 4485000, Expiration: 20230810, Right: C, Date: 20230809, Contract:94: : 94it [03:01,  1.64s/it]
# Root: SPXW, Strike: 4485000, Expiration: 20230810, Right: C, Date: 20230809, Contract:94: : 95it [03:08,  2.36s/it]
# Root: SPXW, Strike: 4495000, Expiration: 20230811, Right: P, Date: 20230809, Contract:95: : 95it [03:08,  2.36s/it]
# Root: SPXW, Strike: 4495000, Expiration: 20230811, Right: C, Date: 20230809, Contract:96: : 95it [03:08,  2.36s/it]
# Root: SPXW, Strike: 4495000, Expiration: 20230811, Right: C, Date: 20230809, Contract:96: : 97it [03:15,  2.69s/it]
# Root: SPXW, Strike: 4490000, Expiration: 20230810, Right: P, Date: 20230809, Contract:97: : 97it [03:15,  2.69s/it]
# Root: SPXW, Strike: 3450000, Expiration: 20230811, Right: P, Date: 20230809, Contract:98: : 97it [03:15,  2.69s/it]
# Root: SPXW, Strike: 3975000, Expiration: 20230811, Right: P, Date: 20230809, Contract:99: : 97it [03:15,  2.69s/it]
# Root: SPXW, Strike: 4490000, Expiration: 20230809, Right: C, Date: 20230809, Contract:100: : 97it [03:15,  2.69s/it]
# Root: SPXW, Strike: 4490000, Expiration: 20230810, Right: C, Date: 20230809, Contract:101: : 97it [03:15,  2.69s/it]
# Root: SPXW, Strike: 4490000, Expiration: 20230810, Right: C, Date: 20230809, Contract:101: : 102it [03:20,  1.87s/it]
# Root: SPXW, Strike: 4490000, Expiration: 20230809, Right: P, Date: 20230809, Contract:102: : 102it [03:20,  1.87s/it]
# Root: SPXW, Strike: 4490000, Expiration: 20230809, Right: P, Date: 20230809, Contract:102: : 103it [03:27,  2.48s/it]
# Root: SPXW, Strike: 4500000, Expiration: 20230811, Right: C, Date: 20230809, Contract:103: : 103it [03:27,  2.48s/it]
# Root: SPXW, Strike: 4500000, Expiration: 20230811, Right: P, Date: 20230809, Contract:104: : 103it [03:27,  2.48s/it]
# Root: SPXW, Strike: 4500000, Expiration: 20230811, Right: P, Date: 20230809, Contract:104: : 105it [03:34,  2.71s/it]
# Root: SPXW, Strike: 3980000, Expiration: 20230811, Right: P, Date: 20230809, Contract:105: : 105it [03:34,  2.71s/it]
# Root: SPXW, Strike: 4495000, Expiration: 20230810, Right: C, Date: 20230809, Contract:106: : 105it [03:34,  2.71s/it]
# Root: SPXW, Strike: 4495000, Expiration: 20230810, Right: P, Date: 20230809, Contract:107: : 105it [03:34,  2.71s/it]
# Root: SPXW, Strike: 4495000, Expiration: 20230810, Right: P, Date: 20230809, Contract:107: : 108it [03:37,  2.05s/it]
# Root: SPXW, Strike: 4505000, Expiration: 20230811, Right: P, Date: 20230809, Contract:108: : 108it [03:37,  2.05s/it]
# Root: SPXW, Strike: 4495000, Expiration: 20230809, Right: C, Date: 20230809, Contract:109: : 108it [03:37,  2.05s/it]
# Root: SPXW, Strike: 4505000, Expiration: 20230811, Right: C, Date: 20230809, Contract:110: : 108it [03:37,  2.05s/it]
# Root: SPXW, Strike: 4505000, Expiration: 20230811, Right: C, Date: 20230809, Contract:110: : 111it [03:39,  1.59s/it]
# Root: SPXW, Strike: 4495000, Expiration: 20230809, Right: P, Date: 20230809, Contract:111: : 111it [03:39,  1.59s/it]
# Root: SPXW, Strike: 4495000, Expiration: 20230809, Right: P, Date: 20230809, Contract:111: : 112it [03:44,  2.08s/it]
# Root: SPXW, Strike: 3975000, Expiration: 20230810, Right: P, Date: 20230809, Contract:112: : 112it [03:44,  2.08s/it]
# Root: SPXW, Strike: 4510000, Expiration: 20230811, Right: P, Date: 20230809, Contract:113: : 112it [03:44,  2.08s/it]
# Root: SPXW, Strike: 4500000, Expiration: 20230810, Right: P, Date: 20230809, Contract:114: : 112it [03:44,  2.08s/it]
# Root: SPXW, Strike: 4510000, Expiration: 20230811, Right: C, Date: 20230809, Contract:115: : 112it [03:44,  2.08s/it]
# Root: SPXW, Strike: 4510000, Expiration: 20230811, Right: C, Date: 20230809, Contract:115: : 116it [03:47,  1.49s/it]
# Root: SPXW, Strike: 4500000, Expiration: 20230810, Right: C, Date: 20230809, Contract:116: : 116it [03:47,  1.49s/it]
# Root: SPXW, Strike: 4500000, Expiration: 20230810, Right: C, Date: 20230809, Contract:116: : 117it [03:51,  1.80s/it]
# Root: SPXW, Strike: 3990000, Expiration: 20230811, Right: P, Date: 20230809, Contract:117: : 117it [03:51,  1.80s/it]
# Root: SPXW, Strike: 4500000, Expiration: 20230809, Right: P, Date: 20230809, Contract:118: : 117it [03:51,  1.80s/it]
# Root: SPXW, Strike: 4515000, Expiration: 20230811, Right: C, Date: 20230809, Contract:119: : 117it [03:51,  1.80s/it]
# Root: SPXW, Strike: 4515000, Expiration: 20230811, Right: P, Date: 20230809, Contract:120: : 117it [03:51,  1.80s/it]
# Root: SPXW, Strike: 4515000, Expiration: 20230811, Right: P, Date: 20230809, Contract:120: : 121it [03:54,  1.34s/it]
# Root: SPXW, Strike: 4500000, Expiration: 20230809, Right: C, Date: 20230809, Contract:121: : 121it [03:54,  1.34s/it]
# Root: SPXW, Strike: 4500000, Expiration: 20230809, Right: C, Date: 20230809, Contract:121: : 122it [03:58,  1.71s/it]
# Root: SPXW, Strike: 4505000, Expiration: 20230810, Right: C, Date: 20230809, Contract:122: : 122it [03:58,  1.71s/it]
# Root: SPXW, Strike: 4505000, Expiration: 20230810, Right: P, Date: 20230809, Contract:123: : 122it [03:58,  1.71s/it]
# Root: SPXW, Strike: 4505000, Expiration: 20230810, Right: P, Date: 20230809, Contract:123: : 124it [04:05,  2.28s/it]
# Root: SPXW, Strike: 4520000, Expiration: 20230811, Right: C, Date: 20230809, Contract:124: : 124it [04:05,  2.28s/it]
# Root: SPXW, Strike: 4520000, Expiration: 20230811, Right: P, Date: 20230809, Contract:125: : 124it [04:05,  2.28s/it]
# Root: SPXW, Strike: 4520000, Expiration: 20230811, Right: P, Date: 20230809, Contract:125: : 126it [04:09,  2.15s/it]
# Root: SPXW, Strike: 4000000, Expiration: 20230811, Right: P, Date: 20230809, Contract:126: : 126it [04:09,  2.15s/it]
# Root: SPXW, Strike: 4000000, Expiration: 20230811, Right: C, Date: 20230809, Contract:127: : 126it [04:09,  2.15s/it]
# Root: SPXW, Strike: 4000000, Expiration: 20230811, Right: C, Date: 20230809, Contract:127: : 128it [04:15,  2.49s/it]
# Root: SPXW, Strike: 4510000, Expiration: 20230810, Right: C, Date: 20230809, Contract:128: : 128it [04:15,  2.49s/it]
# Root: SPXW, Strike: 4510000, Expiration: 20230810, Right: P, Date: 20230809, Contract:129: : 128it [04:15,  2.49s/it]
# Root: SPXW, Strike: 4510000, Expiration: 20230810, Right: P, Date: 20230809, Contract:129: : 130it [04:20,  2.47s/it]
# Root: SPXW, Strike: 4505000, Expiration: 20230809, Right: P, Date: 20230809, Contract:130: : 130it [04:20,  2.47s/it]
# Root: SPXW, Strike: 4525000, Expiration: 20230811, Right: C, Date: 20230809, Contract:131: : 130it [04:20,  2.47s/it]
# Root: SPXW, Strike: 4525000, Expiration: 20230811, Right: P, Date: 20230809, Contract:132: : 130it [04:20,  2.47s/it]
# Root: SPXW, Strike: 4525000, Expiration: 20230811, Right: P, Date: 20230809, Contract:132: : 133it [04:28,  2.45s/it]
# Root: SPXW, Strike: 4505000, Expiration: 20230809, Right: C, Date: 20230809, Contract:133: : 133it [04:28,  2.45s/it]
# Root: SPXW, Strike: 4505000, Expiration: 20230809, Right: C, Date: 20230809, Contract:133: : 134it [04:33,  2.91s/it]
# Root: SPXW, Strike: 4515000, Expiration: 20230810, Right: C, Date: 20230809, Contract:134: : 134it [04:33,  2.91s/it]
# Root: SPXW, Strike: 4515000, Expiration: 20230810, Right: P, Date: 20230809, Contract:135: : 134it [04:33,  2.91s/it]
# Root: SPXW, Strike: 4515000, Expiration: 20230810, Right: P, Date: 20230809, Contract:135: : 136it [04:38,  2.79s/it]
# Root: SPXW, Strike: 4530000, Expiration: 20230811, Right: C, Date: 20230809, Contract:136: : 136it [04:38,  2.79s/it]
# Root: SPXW, Strike: 4530000, Expiration: 20230811, Right: P, Date: 20230809, Contract:137: : 136it [04:38,  2.79s/it]
# Root: SPXW, Strike: 4530000, Expiration: 20230811, Right: P, Date: 20230809, Contract:137: : 138it [04:42,  2.51s/it]
# Root: SPXW, Strike: 4520000, Expiration: 20230810, Right: P, Date: 20230809, Contract:138: : 138it [04:42,  2.51s/it]
# Root: SPXW, Strike: 4010000, Expiration: 20230811, Right: P, Date: 20230809, Contract:139: : 138it [04:42,  2.51s/it]
# Root: SPXW, Strike: 4510000, Expiration: 20230809, Right: P, Date: 20230809, Contract:140: : 138it [04:42,  2.51s/it]
# Root: SPXW, Strike: 4520000, Expiration: 20230810, Right: C, Date: 20230809, Contract:141: : 138it [04:42,  2.51s/it]
# Root: SPXW, Strike: 4520000, Expiration: 20230810, Right: C, Date: 20230809, Contract:141: : 142it [04:47,  2.00s/it]
# Root: SPXW, Strike: 4510000, Expiration: 20230809, Right: C, Date: 20230809, Contract:142: : 142it [04:47,  2.00s/it]
# Root: SPXW, Strike: 4510000, Expiration: 20230809, Right: C, Date: 20230809, Contract:142: : 143it [04:51,  2.21s/it]
# Root: SPXW, Strike: 4535000, Expiration: 20230811, Right: P, Date: 20230809, Contract:143: : 143it [04:51,  2.21s/it]
# Root: SPXW, Strike: 4000000, Expiration: 20230810, Right: P, Date: 20230809, Contract:144: : 143it [04:51,  2.21s/it]
# Root: SPXW, Strike: 4000000, Expiration: 20230810, Right: C, Date: 20230809, Contract:145: : 143it [04:51,  2.21s/it]
# Root: SPXW, Strike: 4000000, Expiration: 20230810, Right: C, Date: 20230809, Contract:145: : 146it [04:57,  2.18s/it]
# Root: SPXW, Strike: 4535000, Expiration: 20230811, Right: C, Date: 20230809, Contract:146: : 146it [04:57,  2.18s/it]
# Root: SPXW, Strike: 4535000, Expiration: 20230811, Right: C, Date: 20230809, Contract:146: : 147it [05:03,  2.76s/it]
# Root: SPXW, Strike: 4515000, Expiration: 20230809, Right: P, Date: 20230809, Contract:147: : 147it [05:03,  2.76s/it]
# Root: SPXW, Strike: 4540000, Expiration: 20230811, Right: P, Date: 20230809, Contract:148: : 147it [05:03,  2.76s/it]
# Root: SPXW, Strike: 4525000, Expiration: 20230810, Right: C, Date: 20230809, Contract:149: : 147it [05:03,  2.76s/it]
# Root: SPXW, Strike: 4515000, Expiration: 20230809, Right: C, Date: 20230809, Contract:150: : 147it [05:03,  2.76s/it]
# Root: SPXW, Strike: 4515000, Expiration: 20230809, Right: C, Date: 20230809, Contract:150: : 151it [05:11,  2.36s/it]
# Root: SPXW, Strike: 4540000, Expiration: 20230811, Right: C, Date: 20230809, Contract:151: : 151it [05:11,  2.36s/it]
# Root: SPXW, Strike: 4540000, Expiration: 20230811, Right: C, Date: 20230809, Contract:151: : 152it [05:21,  3.52s/it]
# Root: SPXW, Strike: 4525000, Expiration: 20230810, Right: P, Date: 20230809, Contract:152: : 152it [05:21,  3.52s/it]
# Root: SPXW, Strike: 4525000, Expiration: 20230810, Right: P, Date: 20230809, Contract:152: : 153it [05:30,  4.45s/it]
# Root: SPXW, Strike: 4020000, Expiration: 20230811, Right: P, Date: 20230809, Contract:153: : 153it [05:30,  4.45s/it]
# Root: SPXW, Strike: 4520000, Expiration: 20230809, Right: P, Date: 20230809, Contract:154: : 153it [05:30,  4.45s/it]
# Root: SPXW, Strike: 4545000, Expiration: 20230811, Right: C, Date: 20230809, Contract:155: : 153it [05:30,  4.45s/it]
# Root: SPXW, Strike: 4545000, Expiration: 20230811, Right: P, Date: 20230809, Contract:156: : 153it [05:30,  4.45s/it]
# Root: SPXW, Strike: 4545000, Expiration: 20230811, Right: P, Date: 20230809, Contract:156: : 157it [05:33,  2.63s/it]
# Root: SPXW, Strike: 4530000, Expiration: 20230810, Right: C, Date: 20230809, Contract:157: : 157it [05:33,  2.63s/it]
# Root: SPXW, Strike: 4520000, Expiration: 20230809, Right: C, Date: 20230809, Contract:158: : 157it [05:33,  2.63s/it]
# Root: SPXW, Strike: 4520000, Expiration: 20230809, Right: C, Date: 20230809, Contract:158: : 159it [05:39,  2.74s/it]
# Root: SPXW, Strike: 4530000, Expiration: 20230810, Right: P, Date: 20230809, Contract:159: : 159it [05:39,  2.74s/it]
# Root: SPXW, Strike: 4530000, Expiration: 20230810, Right: P, Date: 20230809, Contract:159: : 160it [05:43,  2.92s/it]
# Root: SPXW, Strike: 4025000, Expiration: 20230811, Right: P, Date: 20230809, Contract:160: : 160it [05:43,  2.92s/it]
# Root: SPXW, Strike: 4550000, Expiration: 20230811, Right: C, Date: 20230809, Contract:161: : 160it [05:43,  2.92s/it]
# Root: SPXW, Strike: 4550000, Expiration: 20230811, Right: P, Date: 20230809, Contract:162: : 160it [05:43,  2.92s/it]
# Root: SPXW, Strike: 4550000, Expiration: 20230811, Right: P, Date: 20230809, Contract:162: : 163it [05:49,  2.55s/it]
# Root: SPXW, Strike: 4535000, Expiration: 20230810, Right: P, Date: 20230809, Contract:163: : 163it [05:49,  2.55s/it]
# Root: SPXW, Strike: 4535000, Expiration: 20230810, Right: C, Date: 20230809, Contract:164: : 163it [05:49,  2.55s/it]
# Root: SPXW, Strike: 4535000, Expiration: 20230810, Right: C, Date: 20230809, Contract:164: : 165it [05:54,  2.54s/it]
# Root: SPXW, Strike: 4525000, Expiration: 20230809, Right: C, Date: 20230809, Contract:165: : 165it [05:54,  2.54s/it]
# Root: SPXW, Strike: 4525000, Expiration: 20230809, Right: P, Date: 20230809, Contract:166: : 165it [05:54,  2.54s/it]
# Root: SPXW, Strike: 4525000, Expiration: 20230809, Right: P, Date: 20230809, Contract:166: : 167it [06:00,  2.63s/it]
# Root: SPXW, Strike: 5600000, Expiration: 20230811, Right: P, Date: 20230809, Contract:167: : 167it [06:00,  2.63s/it]
# Root: SPXW, Strike: 4030000, Expiration: 20230811, Right: P, Date: 20230809, Contract:168: : 167it [06:00,  2.63s/it]
# Root: SPXW, Strike: 4540000, Expiration: 20230810, Right: P, Date: 20230809, Contract:169: : 167it [06:00,  2.63s/it]
# Root: SPXW, Strike: 4555000, Expiration: 20230811, Right: P, Date: 20230809, Contract:170: : 167it [06:00,  2.63s/it]
# Root: SPXW, Strike: 4555000, Expiration: 20230811, Right: C, Date: 20230809, Contract:171: : 167it [06:00,  2.63s/it]
# Root: SPXW, Strike: 4555000, Expiration: 20230811, Right: C, Date: 20230809, Contract:171: : 172it [06:05,  1.79s/it]
# Root: SPXW, Strike: 4540000, Expiration: 20230810, Right: C, Date: 20230809, Contract:172: : 172it [06:05,  1.79s/it]
# Root: SPXW, Strike: 4540000, Expiration: 20230810, Right: C, Date: 20230809, Contract:172: : 173it [06:08,  1.92s/it]
# Root: SPXW, Strike: 4530000, Expiration: 20230809, Right: C, Date: 20230809, Contract:173: : 173it [06:08,  1.92s/it]
# Root: SPXW, Strike: 4530000, Expiration: 20230809, Right: P, Date: 20230809, Contract:174: : 173it [06:08,  1.92s/it]
# Root: SPXW, Strike: 4530000, Expiration: 20230809, Right: P, Date: 20230809, Contract:174: : 175it [06:10,  1.68s/it]
# Root: SPXW, Strike: 4560000, Expiration: 20230811, Right: P, Date: 20230809, Contract:175: : 175it [06:10,  1.68s/it]
# Root: SPXW, Strike: 4560000, Expiration: 20230811, Right: C, Date: 20230809, Contract:176: : 175it [06:10,  1.68s/it]
# Root: SPXW, Strike: 4560000, Expiration: 20230811, Right: C, Date: 20230809, Contract:176: : 177it [06:16,  2.02s/it]
# Root: SPXW, Strike: 4535000, Expiration: 20230809, Right: P, Date: 20230809, Contract:177: : 177it [06:16,  2.02s/it]
# Root: SPXW, Strike: 4545000, Expiration: 20230810, Right: C, Date: 20230809, Contract:178: : 177it [06:16,  2.02s/it]
# Root: SPXW, Strike: 4535000, Expiration: 20230809, Right: C, Date: 20230809, Contract:179: : 177it [06:16,  2.02s/it]
# Root: SPXW, Strike: 4535000, Expiration: 20230809, Right: C, Date: 20230809, Contract:179: : 180it [06:17,  1.46s/it]
# Root: SPXW, Strike: 4545000, Expiration: 20230810, Right: P, Date: 20230809, Contract:180: : 180it [06:17,  1.46s/it]
# Root: SPXW, Strike: 4545000, Expiration: 20230810, Right: P, Date: 20230809, Contract:180: : 181it [06:22,  1.96s/it]
# Root: SPXW, Strike: 4040000, Expiration: 20230811, Right: P, Date: 20230809, Contract:181: : 181it [06:22,  1.96s/it]
# Root: SPXW, Strike: 3500000, Expiration: 20230810, Right: C, Date: 20230809, Contract:182: : 181it [06:22,  1.96s/it]
# Root: SPXW, Strike: 4565000, Expiration: 20230811, Right: P, Date: 20230809, Contract:183: : 181it [06:22,  1.96s/it]
# Root: SPXW, Strike: 4025000, Expiration: 20230810, Right: P, Date: 20230809, Contract:184: : 181it [06:22,  1.96s/it]
# Root: SPXW, Strike: 4565000, Expiration: 20230811, Right: C, Date: 20230809, Contract:185: : 181it [06:22,  1.96s/it]
# Root: SPXW, Strike: 4565000, Expiration: 20230811, Right: C, Date: 20230809, Contract:185: : 186it [06:35,  2.26s/it]
# Root: SPXW, Strike: 4540000, Expiration: 20230809, Right: P, Date: 20230809, Contract:186: : 186it [06:35,  2.26s/it]
# Root: SPXW, Strike: 4550000, Expiration: 20230810, Right: P, Date: 20230809, Contract:187: : 186it [06:35,  2.26s/it]
# Root: SPXW, Strike: 4540000, Expiration: 20230809, Right: C, Date: 20230809, Contract:188: : 186it [06:35,  2.26s/it]
# Root: SPXW, Strike: 4540000, Expiration: 20230809, Right: C, Date: 20230809, Contract:188: : 189it [06:41,  2.24s/it]
# Root: SPXW, Strike: 4550000, Expiration: 20230810, Right: C, Date: 20230809, Contract:189: : 189it [06:41,  2.24s/it]
# Root: SPXW, Strike: 4550000, Expiration: 20230810, Right: C, Date: 20230809, Contract:189: : 190it [06:47,  2.73s/it]
# Root: SPXW, Strike: 4570000, Expiration: 20230811, Right: C, Date: 20230809, Contract:190: : 190it [06:47,  2.73s/it]
# Root: SPXW, Strike: 4570000, Expiration: 20230811, Right: P, Date: 20230809, Contract:191: : 190it [06:47,  2.73s/it]
# Root: SPXW, Strike: 4570000, Expiration: 20230811, Right: P, Date: 20230809, Contract:191: : 192it [06:55,  2.98s/it]
# Root: SPXW, Strike: 4545000, Expiration: 20230809, Right: C, Date: 20230809, Contract:192: : 192it [06:55,  2.98s/it]
# Root: SPXW, Strike: 4545000, Expiration: 20230809, Right: P, Date: 20230809, Contract:193: : 192it [06:55,  2.98s/it]
# Root: SPXW, Strike: 4545000, Expiration: 20230809, Right: P, Date: 20230809, Contract:193: : 194it [07:00,  2.93s/it]
# Root: SPXW, Strike: 4050000, Expiration: 20230811, Right: P, Date: 20230809, Contract:194: : 194it [07:00,  2.93s/it]
# Root: SPXW, Strike: 1400000, Expiration: 20230809, Right: C, Date: 20230809, Contract:195: : 194it [07:00,  2.93s/it]
# Root: SPXW, Strike: 4555000, Expiration: 20230810, Right: C, Date: 20230809, Contract:196: : 194it [07:00,  2.93s/it]
# Root: SPXW, Strike: 4575000, Expiration: 20230811, Right: C, Date: 20230809, Contract:197: : 194it [07:00,  2.93s/it]
# Root: SPXW, Strike: 4555000, Expiration: 20230810, Right: P, Date: 20230809, Contract:198: : 194it [07:00,  2.93s/it]
# Root: SPXW, Strike: 4555000, Expiration: 20230810, Right: P, Date: 20230809, Contract:198: : 199it [07:08,  2.21s/it]
# Root: SPXW, Strike: 4575000, Expiration: 20230811, Right: P, Date: 20230809, Contract:199: : 199it [07:08,  2.21s/it]
# Root: SPXW, Strike: 4575000, Expiration: 20230811, Right: P, Date: 20230809, Contract:199: : 200it [07:13,  2.63s/it]
# Root: SPXW, Strike: 3500000, Expiration: 20230809, Right: C, Date: 20230809, Contract:200: : 200it [07:13,  2.63s/it]
# Root: SPXW, Strike: 4550000, Expiration: 20230809, Right: C, Date: 20230809, Contract:201: : 200it [07:13,  2.63s/it]
# Root: SPXW, Strike: 4560000, Expiration: 20230810, Right: C, Date: 20230809, Contract:202: : 200it [07:13,  2.63s/it]
# Root: SPXW, Strike: 4550000, Expiration: 20230809, Right: P, Date: 20230809, Contract:203: : 200it [07:13,  2.63s/it]
# Root: SPXW, Strike: 4550000, Expiration: 20230809, Right: P, Date: 20230809, Contract:203: : 204it [07:21,  2.33s/it]
# Root: SPXW, Strike: 4560000, Expiration: 20230810, Right: P, Date: 20230809, Contract:204: : 204it [07:21,  2.33s/it]
# Root: SPXW, Strike: 4560000, Expiration: 20230810, Right: P, Date: 20230809, Contract:204: : 205it [07:27,  2.81s/it]
# Root: SPXW, Strike: 5600000, Expiration: 20230809, Right: P, Date: 20230809, Contract:205: : 205it [07:27,  2.81s/it]
# Root: SPXW, Strike: 4580000, Expiration: 20230811, Right: P, Date: 20230809, Contract:206: : 205it [07:27,  2.81s/it]
# Root: SPXW, Strike: 4580000, Expiration: 20230811, Right: C, Date: 20230809, Contract:207: : 205it [07:27,  2.81s/it]
# Root: SPXW, Strike: 4580000, Expiration: 20230811, Right: C, Date: 20230809, Contract:207: : 208it [07:33,  2.49s/it]
# Root: SPXW, Strike: 4555000, Expiration: 20230809, Right: P, Date: 20230809, Contract:208: : 208it [07:33,  2.49s/it]
# Root: SPXW, Strike: 4565000, Expiration: 20230810, Right: C, Date: 20230809, Contract:209: : 208it [07:33,  2.49s/it]
# Root: SPXW, Strike: 4555000, Expiration: 20230809, Right: C, Date: 20230809, Contract:210: : 208it [07:33,  2.49s/it]
# Root: SPXW, Strike: 4555000, Expiration: 20230809, Right: C, Date: 20230809, Contract:210: : 211it [07:39,  2.33s/it]
# Root: SPXW, Strike: 4565000, Expiration: 20230810, Right: P, Date: 20230809, Contract:211: : 211it [07:39,  2.33s/it]
# Root: SPXW, Strike: 4565000, Expiration: 20230810, Right: P, Date: 20230809, Contract:211: : 212it [07:41,  2.35s/it]
# Root: SPXW, Strike: 4060000, Expiration: 20230811, Right: P, Date: 20230809, Contract:212: : 212it [07:41,  2.35s/it]
# Root: SPXW, Strike: 4585000, Expiration: 20230811, Right: C, Date: 20230809, Contract:213: : 212it [07:41,  2.35s/it]
# Root: SPXW, Strike: 4585000, Expiration: 20230811, Right: P, Date: 20230809, Contract:214: : 212it [07:41,  2.35s/it]
# Root: SPXW, Strike: 4585000, Expiration: 20230811, Right: P, Date: 20230809, Contract:214: : 215it [07:49,  2.47s/it]
# Root: SPXW, Strike: 4560000, Expiration: 20230809, Right: C, Date: 20230809, Contract:215: : 215it [07:49,  2.47s/it]
# Root: SPXW, Strike: 4560000, Expiration: 20230809, Right: P, Date: 20230809, Contract:216: : 215it [07:49,  2.47s/it]
# Root: SPXW, Strike: 4560000, Expiration: 20230809, Right: P, Date: 20230809, Contract:216: : 217it [07:54,  2.50s/it]
# Root: SPXW, Strike: 4570000, Expiration: 20230810, Right: C, Date: 20230809, Contract:217: : 217it [07:54,  2.50s/it]
# Root: SPXW, Strike: 4570000, Expiration: 20230810, Right: P, Date: 20230809, Contract:218: : 217it [07:54,  2.50s/it]
# Root: SPXW, Strike: 4570000, Expiration: 20230810, Right: P, Date: 20230809, Contract:218: : 219it [07:58,  2.34s/it]
# Root: SPXW, Strike: 4050000, Expiration: 20230810, Right: C, Date: 20230809, Contract:219: : 219it [07:58,  2.34s/it]
# Root: SPXW, Strike: 4050000, Expiration: 20230810, Right: P, Date: 20230809, Contract:220: : 219it [07:58,  2.34s/it]
# Root: SPXW, Strike: 4050000, Expiration: 20230810, Right: P, Date: 20230809, Contract:220: : 221it [08:02,  2.16s/it]
# Root: SPXW, Strike: 4590000, Expiration: 20230811, Right: C, Date: 20230809, Contract:221: : 221it [08:02,  2.16s/it]
# Root: SPXW, Strike: 4590000, Expiration: 20230811, Right: P, Date: 20230809, Contract:222: : 221it [08:02,  2.16s/it]
# Root: SPXW, Strike: 4590000, Expiration: 20230811, Right: P, Date: 20230809, Contract:222: : 223it [08:09,  2.55s/it]
# Root: SPXW, Strike: 4565000, Expiration: 20230809, Right: C, Date: 20230809, Contract:223: : 223it [08:09,  2.55s/it]
# Root: SPXW, Strike: 4565000, Expiration: 20230809, Right: P, Date: 20230809, Contract:224: : 223it [08:09,  2.55s/it]
# Root: SPXW, Strike: 4565000, Expiration: 20230809, Right: P, Date: 20230809, Contract:224: : 225it [08:13,  2.51s/it]
# Root: SPXW, Strike: 4575000, Expiration: 20230810, Right: P, Date: 20230809, Contract:225: : 225it [08:13,  2.51s/it]
# Root: SPXW, Strike: 4575000, Expiration: 20230810, Right: C, Date: 20230809, Contract:226: : 225it [08:13,  2.51s/it]
# Root: SPXW, Strike: 4575000, Expiration: 20230810, Right: C, Date: 20230809, Contract:226: : 227it [08:19,  2.66s/it]
# Root: SPXW, Strike: 4070000, Expiration: 20230811, Right: P, Date: 20230809, Contract:227: : 227it [08:19,  2.66s/it]
# Root: SPXW, Strike: 4595000, Expiration: 20230811, Right: C, Date: 20230809, Contract:228: : 227it [08:19,  2.66s/it]
# Root: SPXW, Strike: 4595000, Expiration: 20230811, Right: P, Date: 20230809, Contract:229: : 227it [08:19,  2.66s/it]
# Root: SPXW, Strike: 4595000, Expiration: 20230811, Right: P, Date: 20230809, Contract:229: : 230it [08:24,  2.17s/it]
# Root: SPXW, Strike: 4570000, Expiration: 20230809, Right: C, Date: 20230809, Contract:230: : 230it [08:24,  2.17s/it]
# Root: SPXW, Strike: 4570000, Expiration: 20230809, Right: P, Date: 20230809, Contract:231: : 230it [08:24,  2.17s/it]
# Root: SPXW, Strike: 4570000, Expiration: 20230809, Right: P, Date: 20230809, Contract:231: : 232it [08:28,  2.20s/it]
# Root: SPXW, Strike: 4580000, Expiration: 20230810, Right: C, Date: 20230809, Contract:232: : 232it [08:28,  2.20s/it]
# Root: SPXW, Strike: 4575000, Expiration: 20230809, Right: C, Date: 20230809, Contract:233: : 232it [08:28,  2.20s/it]
# Root: SPXW, Strike: 4580000, Expiration: 20230810, Right: P, Date: 20230809, Contract:234: : 232it [08:28,  2.20s/it]
# Root: SPXW, Strike: 4580000, Expiration: 20230810, Right: P, Date: 20230809, Contract:234: : 235it [08:35,  2.22s/it]
# Root: SPXW, Strike: 4575000, Expiration: 20230809, Right: P, Date: 20230809, Contract:235: : 235it [08:35,  2.22s/it]
# Root: SPXW, Strike: 4575000, Expiration: 20230809, Right: P, Date: 20230809, Contract:235: : 236it [08:40,  2.57s/it]
# Root: SPXW, Strike: 3550000, Expiration: 20230811, Right: P, Date: 20230809, Contract:236: : 236it [08:40,  2.57s/it]
# Root: SPXW, Strike: 4075000, Expiration: 20230811, Right: P, Date: 20230809, Contract:237: : 236it [08:40,  2.57s/it]
# Root: SPXW, Strike: 4600000, Expiration: 20230811, Right: C, Date: 20230809, Contract:238: : 236it [08:40,  2.57s/it]
# Root: SPXW, Strike: 4600000, Expiration: 20230811, Right: P, Date: 20230809, Contract:239: : 236it [08:40,  2.57s/it]
# Root: SPXW, Strike: 4600000, Expiration: 20230811, Right: P, Date: 20230809, Contract:239: : 240it [08:44,  1.90s/it]
# Root: SPXW, Strike: 4585000, Expiration: 20230810, Right: C, Date: 20230809, Contract:240: : 240it [08:44,  1.90s/it]
# Root: SPXW, Strike: 4585000, Expiration: 20230810, Right: P, Date: 20230809, Contract:241: : 240it [08:44,  1.90s/it]
# Root: SPXW, Strike: 4585000, Expiration: 20230810, Right: P, Date: 20230809, Contract:241: : 242it [08:46,  1.67s/it]
# Root: SPXW, Strike: 4580000, Expiration: 20230809, Right: C, Date: 20230809, Contract:242: : 242it [08:46,  1.67s/it]
# Root: SPXW, Strike: 4580000, Expiration: 20230809, Right: P, Date: 20230809, Contract:243: : 242it [08:46,  1.67s/it]
# Root: SPXW, Strike: 4580000, Expiration: 20230809, Right: P, Date: 20230809, Contract:243: : 244it [08:51,  1.94s/it]
# Root: SPXW, Strike: 4080000, Expiration: 20230811, Right: P, Date: 20230809, Contract:244: : 244it [08:51,  1.94s/it]
# Root: SPXW, Strike: 4605000, Expiration: 20230811, Right: C, Date: 20230809, Contract:245: : 244it [08:51,  1.94s/it]
# Root: SPXW, Strike: 4585000, Expiration: 20230809, Right: C, Date: 20230809, Contract:246: : 244it [08:51,  1.94s/it]
# Root: SPXW, Strike: 4590000, Expiration: 20230810, Right: C, Date: 20230809, Contract:247: : 244it [08:51,  1.94s/it]
# Root: SPXW, Strike: 4590000, Expiration: 20230810, Right: P, Date: 20230809, Contract:248: : 244it [08:51,  1.94s/it]
# Root: SPXW, Strike: 4590000, Expiration: 20230810, Right: P, Date: 20230809, Contract:248: : 249it [08:59,  1.79s/it]
# Root: SPXW, Strike: 4585000, Expiration: 20230809, Right: P, Date: 20230809, Contract:249: : 249it [08:59,  1.79s/it]
# Root: SPXW, Strike: 4585000, Expiration: 20230809, Right: P, Date: 20230809, Contract:249: : 250it [09:06,  2.36s/it]
# Root: SPXW, Strike: 4610000, Expiration: 20230811, Right: C, Date: 20230809, Contract:250: : 250it [09:06,  2.36s/it]
# Root: SPXW, Strike: 4610000, Expiration: 20230811, Right: P, Date: 20230809, Contract:251: : 250it [09:06,  2.36s/it]
# Root: SPXW, Strike: 4610000, Expiration: 20230811, Right: P, Date: 20230809, Contract:251: : 252it [09:12,  2.56s/it]
# Root: SPXW, Strike: 4590000, Expiration: 20230809, Right: P, Date: 20230809, Contract:252: : 252it [09:12,  2.56s/it]
# Root: SPXW, Strike: 4590000, Expiration: 20230809, Right: C, Date: 20230809, Contract:253: : 252it [09:12,  2.56s/it]
# Root: SPXW, Strike: 4590000, Expiration: 20230809, Right: C, Date: 20230809, Contract:253: : 254it [09:20,  2.92s/it]
# Root: SPXW, Strike: 4595000, Expiration: 20230810, Right: C, Date: 20230809, Contract:254: : 254it [09:20,  2.92s/it]
# Root: SPXW, Strike: 4595000, Expiration: 20230810, Right: P, Date: 20230809, Contract:255: : 254it [09:20,  2.92s/it]
# Root: SPXW, Strike: 4595000, Expiration: 20230810, Right: P, Date: 20230809, Contract:255: : 256it [09:28,  3.22s/it]
# Root: SPXW, Strike: 4090000, Expiration: 20230811, Right: P, Date: 20230809, Contract:256: : 256it [09:28,  3.22s/it]
# Root: SPXW, Strike: 4075000, Expiration: 20230810, Right: P, Date: 20230809, Contract:257: : 256it [09:28,  3.22s/it]
# Root: SPXW, Strike: 4595000, Expiration: 20230809, Right: C, Date: 20230809, Contract:258: : 256it [09:28,  3.22s/it]
# Root: SPXW, Strike: 4595000, Expiration: 20230809, Right: P, Date: 20230809, Contract:259: : 256it [09:28,  3.22s/it]
# Root: SPXW, Strike: 4595000, Expiration: 20230809, Right: P, Date: 20230809, Contract:259: : 260it [09:36,  2.70s/it]
# Root: SPXW, Strike: 4615000, Expiration: 20230811, Right: P, Date: 20230809, Contract:260: : 260it [09:36,  2.70s/it]
# Root: SPXW, Strike: 4615000, Expiration: 20230811, Right: C, Date: 20230809, Contract:261: : 260it [09:36,  2.70s/it]
# Root: SPXW, Strike: 4615000, Expiration: 20230811, Right: C, Date: 20230809, Contract:261: : 262it [09:44,  2.97s/it]
# Root: SPXW, Strike: 4600000, Expiration: 20230810, Right: C, Date: 20230809, Contract:262: : 262it [09:44,  2.97s/it]
# Root: SPXW, Strike: 4600000, Expiration: 20230810, Right: P, Date: 20230809, Contract:263: : 262it [09:44,  2.97s/it]
# Root: SPXW, Strike: 4600000, Expiration: 20230810, Right: P, Date: 20230809, Contract:263: : 264it [09:51,  3.16s/it]
# Root: SPXW, Strike: 4600000, Expiration: 20230809, Right: C, Date: 20230809, Contract:264: : 264it [09:51,  3.16s/it]
# Root: SPXW, Strike: 4600000, Expiration: 20230809, Right: P, Date: 20230809, Contract:265: : 264it [09:51,  3.16s/it]
# Root: SPXW, Strike: 4600000, Expiration: 20230809, Right: P, Date: 20230809, Contract:265: : 266it [09:55,  2.80s/it]
# Root: SPXW, Strike: 4620000, Expiration: 20230811, Right: C, Date: 20230809, Contract:266: : 266it [09:55,  2.80s/it]
# Root: SPXW, Strike: 4620000, Expiration: 20230811, Right: P, Date: 20230809, Contract:267: : 266it [09:55,  2.80s/it]
# Root: SPXW, Strike: 4620000, Expiration: 20230811, Right: P, Date: 20230809, Contract:267: : 268it [09:56,  2.24s/it]
# Root: SPXW, Strike: 4605000, Expiration: 20230810, Right: C, Date: 20230809, Contract:268: : 268it [09:56,  2.24s/it]
# Root: SPXW, Strike: 4605000, Expiration: 20230809, Right: C, Date: 20230809, Contract:269: : 268it [09:56,  2.24s/it]
# Root: SPXW, Strike: 4605000, Expiration: 20230809, Right: P, Date: 20230809, Contract:270: : 268it [09:56,  2.24s/it]
# Root: SPXW, Strike: 4605000, Expiration: 20230809, Right: P, Date: 20230809, Contract:270: : 271it [10:06,  2.60s/it]
# Root: SPXW, Strike: 4100000, Expiration: 20230811, Right: P, Date: 20230809, Contract:271: : 271it [10:06,  2.60s/it]
# Root: SPXW, Strike: 4610000, Expiration: 20230810, Right: C, Date: 20230809, Contract:272: : 271it [10:06,  2.60s/it]
# Root: SPXW, Strike: 4625000, Expiration: 20230811, Right: C, Date: 20230809, Contract:273: : 271it [10:06,  2.60s/it]
# Root: SPXW, Strike: 4625000, Expiration: 20230811, Right: P, Date: 20230809, Contract:274: : 271it [10:06,  2.60s/it]
# Root: SPXW, Strike: 4625000, Expiration: 20230811, Right: P, Date: 20230809, Contract:274: : 275it [10:20,  2.96s/it]
# Root: SPXW, Strike: 4610000, Expiration: 20230809, Right: C, Date: 20230809, Contract:275: : 275it [10:20,  2.96s/it]
# Root: SPXW, Strike: 4610000, Expiration: 20230809, Right: P, Date: 20230809, Contract:276: : 275it [10:20,  2.96s/it]
# Root: SPXW, Strike: 4610000, Expiration: 20230809, Right: P, Date: 20230809, Contract:276: : 277it [10:26,  2.95s/it]
# Root: SPXW, Strike: 4615000, Expiration: 20230810, Right: C, Date: 20230809, Contract:277: : 277it [10:26,  2.95s/it]
# Root: SPXW, Strike: 4615000, Expiration: 20230810, Right: P, Date: 20230809, Contract:278: : 277it [10:26,  2.95s/it]
# Root: SPXW, Strike: 4615000, Expiration: 20230810, Right: P, Date: 20230809, Contract:278: : 279it [10:31,  2.91s/it]
# Root: SPXW, Strike: 4615000, Expiration: 20230809, Right: C, Date: 20230809, Contract:279: : 279it [10:31,  2.91s/it]
# Root: SPXW, Strike: 4615000, Expiration: 20230809, Right: P, Date: 20230809, Contract:280: : 279it [10:31,  2.91s/it]
# Root: SPXW, Strike: 4615000, Expiration: 20230809, Right: P, Date: 20230809, Contract:280: : 281it [10:40,  3.31s/it]
# Root: SPXW, Strike: 4620000, Expiration: 20230810, Right: C, Date: 20230809, Contract:281: : 281it [10:40,  3.31s/it]
# Root: SPXW, Strike: 4620000, Expiration: 20230810, Right: P, Date: 20230809, Contract:282: : 281it [10:40,  3.31s/it]
# Root: SPXW, Strike: 4620000, Expiration: 20230810, Right: P, Date: 20230809, Contract:282: : 283it [10:52,  3.99s/it]
# Root: SPXW, Strike: 4630000, Expiration: 20230811, Right: C, Date: 20230809, Contract:283: : 283it [10:52,  3.99s/it]
# Root: SPXW, Strike: 4620000, Expiration: 20230809, Right: C, Date: 20230809, Contract:284: : 283it [10:52,  3.99s/it]
# ...
# Root: SPXW, Strike: 4360000, Expiration: 20230809, Right: C, Date: 20230809, Contract:592: : 591it [24:45,  6.83s/it]
# Root: SPXW, Strike: 4360000, Expiration: 20230809, Right: C, Date: 20230809, Contract:592: : 593it [25:02,  7.34s/it]
# Root: SPXW, Strike: 3875000, Expiration: 20230810, Right: P, Date: 20230809, Contract:593: : 593it [25:02,  7.34s/it]
# Root: SPXW, Strike: 4400000, Expiration: 20230810, Right: P, Date: 20230809, Contract:594: : 593it [25:02,  7.34s/it]
# Root: SPXW, Strike: 4400000, Expiration: 20230810, Right: C, Date: 20230809, Contract:595: : 593it [25:02,  7.34s/it]
# Root: SPXW, Strike: 4400000, Expiration: 20230810, Right: C, Date: 20230809, Contract:595: : 596it [25:19,  6.69s/it]
# Root: SPXW, Strike: 4405000, Expiration: 20230810, Right: P, Date: 20230809, Contract:596: : 596it [25:19,  6.69s/it]
# Root: SPXW, Strike: 4405000, Expiration: 20230810, Right: C, Date: 20230809, Contract:597: : 596it [25:19,  6.69s/it]
# Root: SPXW, Strike: 4405000, Expiration: 20230810, Right: C, Date: 20230809, Contract:597: : 598it [25:31,  6.48s/it]
# Root: SPXW, Strike: 4365000, Expiration: 20230809, Right: P, Date: 20230809, Contract:598: : 598it [25:31,  6.48s/it]
# Root: SPXW, Strike: 4365000, Expiration: 20230809, Right: C, Date: 20230809, Contract:599: : 598it [25:31,  6.48s/it]
# Root: SPXW, Strike: 4365000, Expiration: 20230809, Right: C, Date: 20230809, Contract:599: : 600it [25:45,  6.62s/it]
# Root: SPXW, Strike: 4410000, Expiration: 20230810, Right: C, Date: 20230809, Contract:600: : 600it [25:45,  6.62s/it]
# Root: SPXW, Strike: 4410000, Expiration: 20230810, Right: P, Date: 20230809, Contract:601: : 600it [25:45,  6.62s/it]
# Root: SPXW, Strike: 4410000, Expiration: 20230810, Right: P, Date: 20230809, Contract:601: : 602it [25:53,  5.94s/it]
# Root: SPXW, Strike: 4370000, Expiration: 20230809, Right: P, Date: 20230809, Contract:602: : 602it [25:53,  5.94s/it]
# Root: SPXW, Strike: 4370000, Expiration: 20230809, Right: C, Date: 20230809, Contract:603: : 602it [25:53,  5.94s/it]
# Root: SPXW, Strike: 4370000, Expiration: 20230809, Right: C, Date: 20230809, Contract:603: : 604it [26:18,  7.77s/it]
# Root: SPXW, Strike: 4415000, Expiration: 20230810, Right: C, Date: 20230809, Contract:604: : 604it [26:18,  7.77s/it]
# Root: SPXW, Strike: 4415000, Expiration: 20230810, Right: P, Date: 20230809, Contract:605: : 604it [26:18,  7.77s/it]
# Root: SPXW, Strike: 4415000, Expiration: 20230810, Right: P, Date: 20230809, Contract:605: : 606it [26:32,  7.57s/it]
# Root: SPXW, Strike: 4375000, Expiration: 20230809, Right: P, Date: 20230809, Contract:606: : 606it [26:32,  7.57s/it]
# Root: SPXW, Strike: 4375000, Expiration: 20230809, Right: C, Date: 20230809, Contract:607: : 606it [26:32,  7.57s/it]
# Root: SPXW, Strike: 4375000, Expiration: 20230809, Right: C, Date: 20230809, Contract:607: : 608it [26:44,  7.06s/it]
# Root: SPXW, Strike: 4420000, Expiration: 20230810, Right: P, Date: 20230809, Contract:608: : 608it [26:44,  7.06s/it]
# Root: SPXW, Strike: 4420000, Expiration: 20230810, Right: C, Date: 20230809, Contract:609: : 608it [26:44,  7.06s/it]
# Root: SPXW, Strike: 4420000, Expiration: 20230810, Right: C, Date: 20230809, Contract:609: : 610it [26:56,  6.83s/it]
# Root: SPXW, Strike: 4380000, Expiration: 20230809, Right: P, Date: 20230809, Contract:610: : 610it [26:56,  6.83s/it]
# Root: SPXW, Strike: 4380000, Expiration: 20230809, Right: C, Date: 20230809, Contract:611: : 610it [26:56,  6.83s/it]
# Root: SPXW, Strike: 4380000, Expiration: 20230809, Right: C, Date: 20230809, Contract:611: : 612it [27:14,  7.37s/it]
# Root: SPXW, Strike: 4385000, Expiration: 20230809, Right: C, Date: 20230809, Contract:612: : 612it [27:14,  7.37s/it]
# Root: SPXW, Strike: 4385000, Expiration: 20230809, Right: P, Date: 20230809, Contract:613: : 612it [27:14,  7.37s/it]
# Root: SPXW, Strike: 4385000, Expiration: 20230809, Right: P, Date: 20230809, Contract:613: : 614it [27:36,  8.59s/it]
# Root: SPXW, Strike: 4390000, Expiration: 20230809, Right: P, Date: 20230809, Contract:614: : 614it [27:36,  8.59s/it]
# Root: SPXW, Strike: 4390000, Expiration: 20230809, Right: C, Date: 20230809, Contract:615: : 614it [27:36,  8.59s/it]
# Root: SPXW, Strike: 4390000, Expiration: 20230809, Right: C, Date: 20230809, Contract:615: : 616it [27:41,  6.71s/it]
# Root: SPXW, Strike: 4395000, Expiration: 20230809, Right: P, Date: 20230809, Contract:616: : 616it [27:41,  6.71s/it]
# Root: SPXW, Strike: 4395000, Expiration: 20230809, Right: C, Date: 20230809, Contract:617: : 616it [27:41,  6.71s/it]
# Root: SPXW, Strike: 4395000, Expiration: 20230809, Right: C, Date: 20230809, Contract:617: : 618it [27:54,  6.67s/it]
# Root: SPXW, Strike: 4400000, Expiration: 20230809, Right: P, Date: 20230809, Contract:618: : 618it [27:54,  6.67s/it]
# Root: SPXW, Strike: 4400000, Expiration: 20230809, Right: C, Date: 20230809, Contract:619: : 618it [27:54,  6.67s/it]
# Root: SPXW, Strike: 4400000, Expiration: 20230809, Right: C, Date: 20230809, Contract:619: : 620it [28:04,  6.17s/it]
# Root: SPXW, Strike: 4405000, Expiration: 20230809, Right: P, Date: 20230809, Contract:620: : 620it [28:04,  6.17s/it]
# Root: SPXW, Strike: 4405000, Expiration: 20230809, Right: C, Date: 20230809, Contract:621: : 620it [28:04,  6.17s/it]
# Root: SPXW, Strike: 4405000, Expiration: 20230809, Right: C, Date: 20230809, Contract:621: : 622it [28:20,  6.64s/it]
# Root: SPXW, Strike: 4410000, Expiration: 20230809, Right: C, Date: 20230809, Contract:622: : 622it [28:20,  6.64s/it]
# Root: SPXW, Strike: 4410000, Expiration: 20230809, Right: P, Date: 20230809, Contract:623: : 622it [28:20,  6.64s/it]
# Root: SPXW, Strike: 4410000, Expiration: 20230809, Right: P, Date: 20230809, Contract:623: : 624it [28:40,  7.70s/it]
# Root: SPXW, Strike: 4415000, Expiration: 20230809, Right: P, Date: 20230809, Contract:624: : 624it [28:40,  7.70s/it]
# Root: SPXW, Strike: 4415000, Expiration: 20230809, Right: C, Date: 20230809, Contract:625: : 624it [28:40,  7.70s/it]
# Root: SPXW, Strike: 4415000, Expiration: 20230809, Right: C, Date: 20230809, Contract:625: : 626it [28:55,  7.63s/it]
# Root: SPXW, Strike: 4420000, Expiration: 20230809, Right: P, Date: 20230809, Contract:626: : 626it [28:55,  7.63s/it]
# Root: SPXW, Strike: 4420000, Expiration: 20230809, Right: C, Date: 20230809, Contract:627: : 626it [28:55,  7.63s/it]
# Root: SPXW, Strike: 4420000, Expiration: 20230809, Right: C, Date: 20230809, Contract:627: : 628it [29:18,  8.81s/it]
# Root: SPXW, Strike: 3400000, Expiration: 20230809, Right: P, Date: 20230809, Contract:628: : 628it [29:18,  8.81s/it]
# Root: SPXW, Strike: 3400000, Expiration: 20230809, Right: C, Date: 20230809, Contract:629: : 628it [29:18,  8.81s/it]
# Root: SPXW, Strike: 3400000, Expiration: 20230809, Right: C, Date: 20230809, Contract:629: : 630it [29:47, 10.52s/it]
# Root: SPXW, Strike: 1400000, Expiration: 20230809, Right: P, Date: 20230809, Contract:630: : 630it [29:47, 10.52s/it]
# Root: SPXW, Strike: 1400000, Expiration: 20230809, Right: P, Date: 20230809, Contract:630: : 631it [29:57, 10.40s/it]
# Root: SPXW, Strike: 3500000, Expiration: 20230809, Right: P, Date: 20230809, Contract:631: : 631it [29:57, 10.40s/it]
# Root: SPXW, Strike: 3500000, Expiration: 20230809, Right: P, Date: 20230809, Contract:631: : 632it [30:11, 11.07s/it]
# Root: SPXW, Strike: 5600000, Expiration: 20230809, Right: C, Date: 20230809, Contract:632: : 632it [30:11, 11.07s/it]
# Root: SPXW, Strike: 5600000, Expiration: 20230809, Right: C, Date: 20230809, Contract:632: : 633it [30:25, 11.78s/it]
# Root: SPXW, Strike: 3550000, Expiration: 20230809, Right: P, Date: 20230809, Contract:633: : 633it [30:25, 11.78s/it]
# Root: SPXW, Strike: 3550000, Expiration: 20230809, Right: C, Date: 20230809, Contract:634: : 633it [30:25, 11.78s/it]
# Root: SPXW, Strike: 3550000, Expiration: 20230809, Right: C, Date: 20230809, Contract:634: : 635it [30:39,  9.97s/it]
# Root: SPXW, Strike: 3600000, Expiration: 20230809, Right: P, Date: 20230809, Contract:635: : 635it [30:39,  9.97s/it]
# Root: SPXW, Strike: 3600000, Expiration: 20230809, Right: C, Date: 20230809, Contract:636: : 635it [30:39,  9.97s/it]
# Root: SPXW, Strike: 3600000, Expiration: 20230809, Right: C, Date: 20230809, Contract:636: : 637it [30:44,  7.22s/it]
# Root: SPXW, Strike: 3650000, Expiration: 20230809, Right: P, Date: 20230809, Contract:637: : 637it [30:44,  7.22s/it]
# Root: SPXW, Strike: 3650000, Expiration: 20230809, Right: C, Date: 20230809, Contract:638: : 637it [30:44,  7.22s/it]
# Root: SPXW, Strike: 3650000, Expiration: 20230809, Right: C, Date: 20230809, Contract:638: : 639it [30:52,  6.13s/it]
# Root: SPXW, Strike: 1600000, Expiration: 20230809, Right: P, Date: 20230809, Contract:639: : 639it [30:52,  6.13s/it]
# Root: SPXW, Strike: 1600000, Expiration: 20230809, Right: P, Date: 20230809, Contract:639: : 640it [31:02,  7.01s/it]
# Root: SPXW, Strike: 3700000, Expiration: 20230809, Right: P, Date: 20230809, Contract:640: : 640it [31:02,  7.01s/it]
# Root: SPXW, Strike: 3700000, Expiration: 20230809, Right: C, Date: 20230809, Contract:641: : 640it [31:02,  7.01s/it]
# Root: SPXW, Strike: 3700000, Expiration: 20230809, Right: C, Date: 20230809, Contract:641: : 642it [31:12,  6.23s/it]
# Root: SPXW, Strike: 3750000, Expiration: 20230809, Right: P, Date: 20230809, Contract:642: : 642it [31:12,  6.23s/it]
# Root: SPXW, Strike: 3750000, Expiration: 20230809, Right: C, Date: 20230809, Contract:643: : 642it [31:12,  6.23s/it]
# Root: SPXW, Strike: 3750000, Expiration: 20230809, Right: C, Date: 20230809, Contract:643: : 644it [31:19,  5.29s/it]
# Root: SPXW, Strike: 3800000, Expiration: 20230809, Right: P, Date: 20230809, Contract:644: : 644it [31:19,  5.29s/it]
# Root: SPXW, Strike: 3800000, Expiration: 20230809, Right: C, Date: 20230809, Contract:645: : 644it [31:19,  5.29s/it]
# Root: SPXW, Strike: 3800000, Expiration: 20230809, Right: C, Date: 20230809, Contract:645: : 646it [31:28,  4.96s/it]
# Root: SPXW, Strike: 3850000, Expiration: 20230809, Right: P, Date: 20230809, Contract:646: : 646it [31:28,  4.96s/it]
# Root: SPXW, Strike: 3850000, Expiration: 20230809, Right: C, Date: 20230809, Contract:647: : 646it [31:28,  4.96s/it]
# Root: SPXW, Strike: 3850000, Expiration: 20230809, Right: C, Date: 20230809, Contract:647: : 648it [31:37,  4.88s/it]
# Root: SPXW, Strike: 1800000, Expiration: 20230809, Right: P, Date: 20230809, Contract:648: : 648it [31:37,  4.88s/it]
# Root: SPXW, Strike: 1800000, Expiration: 20230809, Right: C, Date: 20230809, Contract:649: : 648it [31:37,  4.88s/it]
# Root: SPXW, Strike: 1800000, Expiration: 20230809, Right: C, Date: 20230809, Contract:649: : 650it [31:42,  4.09s/it]
# Root: SPXW, Strike: 3900000, Expiration: 20230809, Right: C, Date: 20230809, Contract:650: : 650it [31:42,  4.09s/it]
# Root: SPXW, Strike: 3900000, Expiration: 20230809, Right: P, Date: 20230809, Contract:651: : 650it [31:42,  4.09s/it]
# Root: SPXW, Strike: 3900000, Expiration: 20230809, Right: P, Date: 20230809, Contract:651: : 652it [31:46,  3.45s/it]
# Root: SPXW, Strike: 3950000, Expiration: 20230809, Right: P, Date: 20230809, Contract:652: : 652it [31:46,  3.45s/it]
# Root: SPXW, Strike: 3950000, Expiration: 20230809, Right: P, Date: 20230809, Contract:652: : 653it [31:50,  3.63s/it]
# Root: SPXW, Strike: 4050000, Expiration: 20230809, Right: P, Date: 20230809, Contract:653: : 653it [31:50,  3.63s/it]
# Root: SPXW, Strike: 4050000, Expiration: 20230809, Right: P, Date: 20230809, Contract:653: : 654it [31:53,  3.47s/it]
# Root: SPXW, Strike: 4075000, Expiration: 20230809, Right: C, Date: 20230809, Contract:654: : 654it [31:53,  3.47s/it]
# Root: SPXW, Strike: 4075000, Expiration: 20230809, Right: P, Date: 20230809, Contract:655: : 654it [31:53,  3.47s/it]
# Root: SPXW, Strike: 4075000, Expiration: 20230809, Right: P, Date: 20230809, Contract:655: : 656it [31:56,  2.69s/it]
# Root: SPXW, Strike: 2000000, Expiration: 20230809, Right: C, Date: 20230809, Contract:656: : 656it [31:56,  2.69s/it]
# Root: SPXW, Strike: 2000000, Expiration: 20230809, Right: P, Date: 20230809, Contract:657: : 656it [31:56,  2.69s/it]
# Root: SPXW, Strike: 2000000, Expiration: 20230809, Right: P, Date: 20230809, Contract:657: : 658it [31:59,  2.32s/it]
# Root: SPXW, Strike: 4100000, Expiration: 20230809, Right: C, Date: 20230809, Contract:658: : 658it [31:59,  2.32s/it]
# Root: SPXW, Strike: 4100000, Expiration: 20230809, Right: P, Date: 20230809, Contract:659: : 658it [31:59,  2.32s/it]
# Root: SPXW, Strike: 4100000, Expiration: 20230809, Right: P, Date: 20230809, Contract:659: : 660it [32:01,  1.89s/it]
# Root: SPXW, Strike: 4125000, Expiration: 20230809, Right: P, Date: 20230809, Contract:660: : 660it [32:01,  1.89s/it]
# Root: SPXW, Strike: 4125000, Expiration: 20230809, Right: P, Date: 20230809, Contract:660: : 661it [32:03,  1.84s/it]
# Root: SPXW, Strike: 4150000, Expiration: 20230809, Right: P, Date: 20230809, Contract:661: : 661it [32:03,  1.84s/it]
# Root: SPXW, Strike: 4150000, Expiration: 20230809, Right: P, Date: 20230809, Contract:661: : 662it [32:04,  1.75s/it]
# Root: SPXW, Strike: 4170000, Expiration: 20230809, Right: P, Date: 20230809, Contract:662: : 662it [32:04,  1.75s/it]
# Root: SPXW, Strike: 4170000, Expiration: 20230809, Right: P, Date: 20230809, Contract:662: : 663it [32:07,  1.94s/it]
# Root: SPXW, Strike: 4175000, Expiration: 20230809, Right: P, Date: 20230809, Contract:663: : 663it [32:07,  1.94s/it]
# Root: SPXW, Strike: 4175000, Expiration: 20230809, Right: P, Date: 20230809, Contract:663: : 664it [32:08,  1.88s/it]
# Root: SPXW, Strike: 4180000, Expiration: 20230809, Right: C, Date: 20230809, Contract:664: : 664it [32:08,  1.88s/it]
# Root: SPXW, Strike: 4180000, Expiration: 20230809, Right: C, Date: 20230809, Contract:664: : 665it [32:10,  1.84s/it]
# Root: SPXW, Strike: 4240000, Expiration: 20230809, Right: P, Date: 20230809, Contract:665: : 665it [32:10,  1.84s/it]
# Root: SPXW, Strike: 4240000, Expiration: 20230809, Right: P, Date: 20230809, Contract:665: : 666it [32:11,  1.67s/it]
# Root: SPXW, Strike: 4255000, Expiration: 20230809, Right: P, Date: 20230809, Contract:666: : 666it [32:11,  1.67s/it]
# Root: SPXW, Strike: 4255000, Expiration: 20230809, Right: P, Date: 20230809, Contract:666: : 667it [32:13,  1.69s/it]
# Root: SPXW, Strike: 4260000, Expiration: 20230809, Right: C, Date: 20230809, Contract:667: : 667it [32:13,  1.69s/it]
# Root: SPXW, Strike: 4260000, Expiration: 20230809, Right: C, Date: 20230809, Contract:667: : 668it [32:14,  1.63s/it]
# Root: SPXW, Strike: 4265000, Expiration: 20230809, Right: C, Date: 20230809, Contract:668: : 668it [32:14,  1.63s/it]
# Root: SPXW, Strike: 4265000, Expiration: 20230809, Right: C, Date: 20230809, Contract:668: : 669it [32:16,  1.57s/it]
# Root: SPXW, Strike: 4270000, Expiration: 20230809, Right: C, Date: 20230809, Contract:669: : 669it [32:16,  1.57s/it]
# Root: SPXW, Strike: 4270000, Expiration: 20230809, Right: C, Date: 20230809, Contract:669: : 670it [32:17,  1.46s/it]
# Root: SPXW, Strike: 4275000, Expiration: 20230809, Right: C, Date: 20230809, Contract:670: : 670it [32:17,  1.46s/it]
# Root: SPXW, Strike: 4275000, Expiration: 20230809, Right: C, Date: 20230809, Contract:670: : 671it [32:18,  1.30s/it]
# Root: SPXW, Strike: 4285000, Expiration: 20230809, Right: P, Date: 20230809, Contract:671: : 671it [32:18,  1.30s/it]
# Root: SPXW, Strike: 4285000, Expiration: 20230809, Right: P, Date: 20230809, Contract:671: : 672it [32:19,  1.29s/it]
# Root: SPXW, Strike: 2200000, Expiration: 20230809, Right: P, Date: 20230809, Contract:672: : 672it [32:19,  1.29s/it]
# Root: SPXW, Strike: 2200000, Expiration: 20230809, Right: C, Date: 20230809, Contract:673: : 672it [32:19,  1.29s/it]
# Root: SPXW, Strike: 2200000, Expiration: 20230809, Right: C, Date: 20230809, Contract:673: : 674it [32:21,  1.01it/s]
# Root: SPXW, Strike: 4305000, Expiration: 20230809, Right: C, Date: 20230809, Contract:674: : 674it [32:21,  1.01it/s]
# Root: SPXW, Strike: 4305000, Expiration: 20230809, Right: C, Date: 20230809, Contract:674: : 675it [32:22,  1.07s/it]
# Root: SPXW, Strike: 4315000, Expiration: 20230809, Right: C, Date: 20230809, Contract:675: : 675it [32:22,  1.07s/it]

# %%
print("complete")

# %%
470
430+

# %%
164++164+164
